# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
 
# %matplotlib inline

# %%
df = pd.read_excel("Project_Data_set.xlsx", index_col = None)

# %%
df = df.loc[df['DEPNDMRJ'] == 0]

# %%
df.head()
# Out:
#    Unnamed: 0  CASEID  HEALTH2  AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  K6SCMON  \
# 0           0       1      2.0    17         3         4       2.0        0
# 1           1       2      2.0     8         3         2       1.0       12
# 2           2       3      3.0    13         2         1       1.0       12
# 3           3       4      3.0    16         2         1       2.0       15
# 4           4       5      2.0    16         4         1       3.0        0
#
#       K6SCYR  K6SCMAX  ...  NODR30A  DR5DAY  MJEVER  MJYRTOT  MRDAYPYR  \
# 0  10.291153        0  ...      0.0     0.0       2      0.0  0.000000
# 1  21.000000       21  ...      5.0     1.0       1    104.0  3.153398
# 2  10.291153       12  ...      0.0     0.0       2      0.0  0.000000
# 3  24.000000       24  ...      2.0     0.0       1      0.0  0.000000
# 4  10.291153        0  ...      0.0     0.0       2      0.0  0.000000
#
#     MRDAYPMO  MRDAYPWK  MJDAY30A  DEPNDALC  DEPNDMRJ
# 0   0.000000       0.0       0.0         0         0
# 1  14.484054       2.0       1.0         0         0
# 2   0.000000       0.0       0.0         0         0
# 3   0.000000       0.0       0.0         0         0
# 4   0.000000       0.0       0.0         0         0
#
# [5 rows x 26 columns]

# %%
df= df[['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4',
       'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCYRTOT',
       'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY',
       'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A',
       'DEPNDALC']]

# %%
df.corr()
# Out:
#             CASEID   HEALTH2      AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  \
# CASEID    1.000000  0.002681 -0.001593 -0.006912  0.002983 -0.011761
# HEALTH2   0.002681  1.000000  0.170294 -0.244652  0.190001 -0.161323
# AGE2     -0.001593  0.170294  1.000000  0.167040 -0.001693  0.215281
# EDUCCAT2 -0.006912 -0.244652  0.167040  1.000000 -0.209121  0.358106
# EMPSTAT4  0.002983  0.190001 -0.001693 -0.209121  1.000000 -0.268180
# POVERTY2 -0.011761 -0.161323  0.215281  0.358106 -0.268180  1.000000
# K6SCMON  -0.001095  0.209607 -0.181383 -0.075684  0.100997 -0.155900
# K6SCYR    0.003027  0.100685 -0.123834 -0.077345  0.055338 -0.098927
# K6SCMAX   0.002496  0.176198 -0.190263 -0.033316  0.074949 -0.128120
# ALCYRTOT  0.001619 -0.073461  0.094719  0.156778 -0.124589  0.133335
# ALDAYPYR -0.005555 -0.018187  0.045169  0.044223 -0.034921  0.055135
# ALDAYPMO -0.000176 -0.028568 -0.030674  0.039562 -0.052149  0.020904
# ALDAYPWK -0.009798 -0.026920 -0.074748  0.062983 -0.090386  0.038047
# ALCDAYS   0.001629 -0.080623  0.096965  0.169784 -0.118694  0.141687
# NODR30A   0.010477  0.023723 -0.009355 -0.058377 -0.006009 -0.041384
# DR5DAY    0.002854  0.012112 -0.046142 -0.019374 -0.069223  0.006009
# MJEVER   -0.000983 -0.010387  0.012984 -0.002760  0.028265 -0.003616
# MJYRTOT  -0.004694  0.042588 -0.140473 -0.076925 -0.009781 -0.066981
# MRDAYPYR -0.002536  0.017362 -0.049193 -0.038241 -0.004380 -0.015190
# MRDAYPMO  0.006837 -0.016299 -0.173343  0.018129 -0.018844 -0.026883
# MRDAYPWK  0.000268 -0.001833 -0.223682 -0.014486 -0.018179 -0.061935
# MJDAY30A -0.001759  0.044940 -0.119863 -0.069969 -0.013246 -0.059335
# DEPNDALC -0.003400  0.032754 -0.046687 -0.014596 -0.011616 -0.028750
#
#            K6SCMON    K6SCYR   K6SCMAX  ALCYRTOT  ...   ALCDAYS   NODR30A  \
# CASEID   -0.001095  0.003027  0.002496  0.001619  ...  0.001629  0.010477
# HEALTH2   0.209607  0.100685  0.176198 -0.073461  ... -0.080623  0.023723
# AGE2     -0.181383 -0.123834 -0.190263  0.094719  ...  0.096965 -0.009355
# EDUCCAT2 -0.075684 -0.077345 -0.033316  0.156778  ...  0.169784 -0.058377
# EMPSTAT4  0.100997  0.055338  0.074949 -0.124589  ... -0.118694 -0.006009
# POVERTY2 -0.155900 -0.098927 -0.128120  0.133335  ...  0.141687 -0.041384
# K6SCMON   1.000000  0.430079  0.867655 -0.005496  ... -0.011500  0.026079
# K6SCYR    0.430079  1.000000  0.571731 -0.016169  ... -0.019599  0.015647
# K6SCMAX   0.867655  0.571731  1.000000 -0.004895  ... -0.008199  0.014613
# ALCYRTOT -0.005496 -0.016169 -0.004895  1.000000  ...  0.815371  0.022565
# ALDAYPYR -0.008415  0.002921 -0.006259  0.294041  ...  0.286991  0.012637
# ALDAYPMO  0.012469 -0.000624  0.013350  0.308216  ...  0.163669  0.011566
# ALDAYPWK  0.017877  0.018633  0.040026 -0.127625  ... -0.114290  0.047685
# ALCDAYS  -0.011500 -0.019599 -0.008199  0.815371  ...  1.000000 -0.007730
# NODR30A   0.026079  0.015647  0.014613  0.022565  ... -0.007730  1.000000
# DR5DAY    0.041146  0.028968  0.033321  0.470376  ...  0.557104  0.122992
# MJEVER   -0.034831 -0.015421 -0.041728 -0.059011  ... -0.057986 -0.006505
# MJYRTOT   0.082401  0.055120  0.077715  0.139458  ...  0.131486  0.026126
# MRDAYPYR  0.027722  0.021946  0.025915  0.051259  ...  0.046747  0.005893
# MRDAYPMO  0.100243  0.070142  0.116676  0.131482  ...  0.130749  0.010271
# MRDAYPWK  0.118909  0.084938  0.134205  0.171400  ...  0.167127  0.018108
# MJDAY30A  0.074996  0.049442  0.071614  0.128700  ...  0.135543  0.021672
# DEPNDALC  0.151805  0.082044  0.147219  0.238619  ...  0.224351  0.028137
#
#             DR5DAY    MJEVER   MJYRTOT  MRDAYPYR  MRDAYPMO  MRDAYPWK  \
# CASEID    0.002854 -0.000983 -0.004694 -0.002536  0.006837  0.000268
# HEALTH2   0.012112 -0.010387  0.042588  0.017362 -0.016299 -0.001833
# AGE2     -0.046142  0.012984 -0.140473 -0.049193 -0.173343 -0.223682
# EDUCCAT2 -0.019374 -0.002760 -0.076925 -0.038241  0.018129 -0.014486
# EMPSTAT4 -0.069223  0.028265 -0.009781 -0.004380 -0.018844 -0.018179
# POVERTY2  0.006009 -0.003616 -0.066981 -0.015190 -0.026883 -0.061935
# K6SCMON   0.041146 -0.034831  0.082401  0.027722  0.100243  0.118909
# K6SCYR    0.028968 -0.015421  0.055120  0.021946  0.070142  0.084938
# K6SCMAX   0.033321 -0.041728  0.077715  0.025915  0.116676  0.134205
# ALCYRTOT  0.470376 -0.059011  0.139458  0.051259  0.131482  0.171400
# ALDAYPYR  0.182926 -0.019741  0.055977  0.078802  0.059970  0.060108
# ALDAYPMO  0.088908 -0.025587  0.067487  0.040546  0.062300  0.089673
# ALDAYPWK -0.069403 -0.017954  0.040854  0.019138  0.054107  0.063122
# ALCDAYS   0.557104 -0.057986  0.131486  0.046747  0.130749  0.167127
# NODR30A   0.122992 -0.006505  0.026126  0.005893  0.010271  0.018108
# DR5DAY    1.000000 -0.045318  0.184085  0.065545  0.136931  0.193279
# MJEVER   -0.045318  1.000000 -0.057822 -0.021777 -0.062749 -0.021021
# MJYRTOT   0.184085 -0.057822  1.000000  0.373292  0.191229  0.431142
# MRDAYPYR  0.065545 -0.021777  0.373292  1.000000  0.344725  0.271201
# MRDAYPMO  0.136931 -0.062749  0.191229  0.344725  1.000000  0.818588
# MRDAYPWK  0.193279 -0.021021  0.431142  0.271201  0.818588  1.000000
# MJDAY30A  0.182557 -0.050726  0.898672  0.361205  0.201549  0.391490
# DEPNDALC  0.302599 -0.025271  0.083296  0.037235  0.096588  0.125305
#
#           MJDAY30A  DEPNDALC
# CASEID   -0.001759 -0.003400
# HEALTH2   0.044940  0.032754
# AGE2     -0.119863 -0.046687
# EDUCCAT2 -0.069969 -0.014596
# EMPSTAT4 -0.013246 -0.011616
# POVERTY2 -0.059335 -0.028750
# K6SCMON   0.074996  0.151805
# K6SCYR    0.049442  0.082044
# K6SCMAX   0.071614  0.147219
# ALCYRTOT  0.128700  0.238619
# ALDAYPYR  0.055006  0.076721
# ALDAYPMO  0.059538  0.050874
# ALDAYPWK  0.035702 -0.035769
# ALCDAYS   0.135543  0.224351
# NODR30A   0.021672  0.028137
# DR5DAY    0.182557  0.302599
# MJEVER   -0.050726 -0.025271
# MJYRTOT   0.898672  0.083296
# MRDAYPYR  0.361205  0.037235
# MRDAYPMO  0.201549  0.096588
# MRDAYPWK  0.391490  0.125305
# MJDAY30A  1.000000  0.078595
# DEPNDALC  0.078595  1.000000
#
# [23 rows x 23 columns]

# %%
col_names = list(df)
print (col_names)
# Out:
# ['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCEVER', 'ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJEVER', 'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDALC', 'DEPNDMRJ']

# %%
#create df for alcohol, weed and K6 variables

# %%
df_alc= df[['ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY']]
df_mr= df[['MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A']]
df_K6 = df[['K6SCMON', 'K6SCYR', 'K6SCMAX']]

# %%
#PCA visualisation

# %% [markdown]
# PCA is effected by scale so we need to scale the features in our data before applying PCA. Use StandardScaler to help  standardize the dataset’s features onto unit scale (mean = 0 and variance = 1) which is a requirement for the optimal performance of many machine learning algorithms.

# %%
#standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled_data_alc= StandardScaler().fit_transform(df_alc)
scaled_data_mr= StandardScaler().fit_transform(df_mr)
scaled_data_K6= StandardScaler().fit_transform(df_K6)

# %% [markdown]
# scaled_data_alc= df_alc.apply(np.log)
# scaled_data_mr= df_mr.apply(np.log)
# scaled_data_K6= df_K6.apply(np.log)

# %% [markdown]
# scaled_data_alc.head()

# %%
df_alc.shape
# Out:
# (39892, 7)

# %%
df_mr.shape
# Out:
# (39892, 5)

# %%
df_K6.shape
# Out:
# (39892, 3)

# %%
#PCA with Scikit Learn uses a very similar process to other preprocessing functions that come with SciKit Learn. 
#We instantiate a PCA object, find the principal components using the fit method, then apply the rotation and dimensionality reduction by calling transform().
#We can also specify how many components we want to keep when creating the PCA object.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1) #set how many dimensions

# %%
x_pca_alc =pca.fit_transform(scaled_data_alc)
x_pca_mr =pca.fit_transform(scaled_data_mr)
x_pca_K6 =pca.fit_transform(scaled_data_K6)

# %%
#Now we can transform this data to its first principal component.

# %%
scaled_data_alc.shape #shape before
# Out:
# (39892, 7)

# %%
x_pca_alc.shape  #shape after (to check if worked)
# Out:
# (39892, 1)

# %% [markdown]
# We've reduced the 7,5 and 3 dimensions to just 1.

# %%
#Unfortunately, with this great power of dimensionality reduction, comes the cost of being able to easily understand what these components represent.
#The components correspond to combinations of the original features, the components themselves are stored as an attribute of the fitted PCA object:

# %%
df_comp_alc =pd.DataFrame(data=x_pca_alc, columns= ['PCA_alcohol1'])
df_comp_mr =pd.DataFrame(data=x_pca_alc, columns= ['PCA_marijuana'])
df_comp_K6 =pd.DataFrame(data=x_pca_alc, columns= ['PCA K6'])

# %%
#now do regression on PCA data instead of whole df

# %% [markdown]
# ##Regression on PCA

# %%
df.columns
# Out:
# Index(['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2',
#        'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCEVER', 'ALCYRTOT', 'ALDAYPYR',
#        'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJEVER',
#        'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDALC',
#        'DEPNDMRJ'],
#       dtype='object')

# %%
df_PCA =df[['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX']]

# %%
df_PCA=df_PCA.assign(x_pca_alc = x_pca_alc, x_pca_mr=x_pca_mr, x_pca_K6=x_pca_K6)

# %%
df_PCA.describe()
# Out:
#              CASEID       HEALTH2          AGE2      EDUCCAT2      EMPSTAT4  \
# count  39892.000000  39892.000000  39892.000000  39892.000000  39892.000000
# mean   27670.128547      2.254511     13.499072      2.720345      2.018099
# std    15955.343138      0.942880      2.683112      1.015660      1.254277
# min        1.000000      1.000000      7.000000      1.000000      1.000000
# 25%    13826.500000      2.000000     12.000000      2.000000      1.000000
# 50%    27705.500000      2.000000     14.000000      3.000000      1.000000
# 75%    41531.250000      3.000000     15.000000      4.000000      3.000000
# max    55270.000000      4.000000     17.000000      4.000000      4.000000
#
#            POVERTY2       K6SCMON        K6SCYR       K6SCMAX     x_pca_alc  \
# count  39892.000000  39892.000000  39892.000000  39892.000000  3.989200e+04
# mean       2.411205      4.137722     10.215204      5.377996 -4.377376e-17
# std        0.784285      4.396248      3.464920      5.698629  1.568221e+00
# min        1.000000      0.000000      0.000000      0.000000 -1.148702e+00
# 25%        2.000000      1.000000     10.291153      1.000000 -1.123876e+00
# 50%        3.000000      3.000000     10.291153      4.000000 -6.000879e-01
# 75%        3.000000      6.000000     10.291153      8.000000  4.767023e-01
# max        3.000000     24.000000     24.000000     24.000000  1.198209e+01
#
#            x_pca_mr      x_pca_K6
# count  3.989200e+04  3.989200e+04
# mean   5.582731e-16  1.004912e-16
# std    1.654954e+00  1.505219e+00
# min   -6.231994e-01 -2.605419e+00
# 25%   -6.231994e-01 -1.151039e+00
# 50%   -6.231994e-01 -4.085331e-01
# 75%   -6.231994e-01  5.814746e-01
# max    1.305519e+01  6.726387e+00

# %%
sns.distplot(df_PCA['x_pca_K6'])
# Out:
# C:\Users\sharl\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(df_PCA) #creates histogram and correlation  scater plots

# %%
df_PCA.corr()
# Out:
#              CASEID   HEALTH2      AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  \
# CASEID     1.000000  0.002681 -0.001593 -0.006912  0.002983 -0.011761
# HEALTH2    0.002681  1.000000  0.170294 -0.244652  0.190001 -0.161323
# AGE2      -0.001593  0.170294  1.000000  0.167040 -0.001693  0.215281
# EDUCCAT2  -0.006912 -0.244652  0.167040  1.000000 -0.209121  0.358106
# EMPSTAT4   0.002983  0.190001 -0.001693 -0.209121  1.000000 -0.268180
# POVERTY2  -0.011761 -0.161323  0.215281  0.358106 -0.268180  1.000000
# K6SCMON   -0.001095  0.209607 -0.181383 -0.075684  0.100997 -0.155900
# K6SCYR     0.003027  0.100685 -0.123834 -0.077345  0.055338 -0.098927
# K6SCMAX    0.002496  0.176198 -0.190263 -0.033316  0.074949 -0.128120
# x_pca_alc  0.001444 -0.059026  0.061661  0.124849 -0.121781  0.113704
# x_pca_mr  -0.000701  0.025019 -0.194742 -0.051345 -0.017619 -0.065045
# x_pca_K6   0.001597  0.190365 -0.192555 -0.069335  0.089764 -0.148178
#
#             K6SCMON    K6SCYR   K6SCMAX  x_pca_alc  x_pca_mr  x_pca_K6
# CASEID    -0.001095  0.003027  0.002496   0.001444 -0.000701  0.001597
# HEALTH2    0.209607  0.100685  0.176198  -0.059026  0.025019  0.190365
# AGE2      -0.181383 -0.123834 -0.190263   0.061661 -0.194742 -0.192555
# EDUCCAT2  -0.075684 -0.077345 -0.033316   0.124849 -0.051345 -0.069335
# EMPSTAT4   0.100997  0.055338  0.074949  -0.121781 -0.017619  0.089764
# POVERTY2  -0.155900 -0.098927 -0.128120   0.113704 -0.065045 -0.148178
# K6SCMON    1.000000  0.430079  0.867655   0.006486  0.111445  0.903212
# K6SCYR     0.430079  1.000000  0.571731  -0.003975  0.077399  0.737048
# K6SCMAX    0.867655  0.571731  1.000000   0.005496  0.117136  0.952153
# x_pca_alc  0.006486 -0.003975  0.005496   1.000000  0.213687  0.003602
# x_pca_mr   0.111445  0.077399  0.117136   0.213687  1.000000  0.118836
# x_pca_K6   0.903212  0.737048  0.952153   0.003602  0.118836  1.000000

# %%
sns.heatmap(df_PCA.corr(), annot=True)

# %%
df_PCA.columns
# Out:
# Index(['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2',
#        'K6SCMON', 'K6SCYR', 'K6SCMAX', 'x_pca_alc', 'x_pca_mr', 'x_pca_K6'],
#       dtype='object')

# %% [markdown]
# Training a linear reg model with scikit.
# Split the data into features to train on (x array) and target variable(y).

# %%
X = df_PCA[['HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'x_pca_alc', 'x_pca_mr']] #education and employment is non linear, maybe better logistic regression

# %%
y = df_PCA['K6SCMON']

# %%
from sklearn.model_selection  import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101) #40% test, #random split seed 101

# %% [markdown]
# create and train the model

# %%
from sklearn.linear_model import LinearRegression #import a reg model

# %%
lm = LinearRegression()  #initiate and instance of regression model

# %%
lm.fit(X_train, y_train) #train/fit my model on training data
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#evaluate the model, check it's coefficient and see how can be interpreted

# %%
print(lm.intercept_)  #print the intercept
# Out:
# 6.17164501316104

# %%
lm.coef_ #grab the coefficience for each feautre
# Out:
# array([ 1.06359927, -0.32716503,  0.23919609,  0.18109278, -0.43143054,
#         0.08237092,  0.15780188])

# %%
X_train.columns
# Out:
# Index(['HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'x_pca_alc',
#        'x_pca_mr'],
#       dtype='object')

# %%
cdf = pd.DataFrame(lm.coef_,X_train.columns, columns=['coefficient'])

# %%
cdf #cdf as coefficient dataFrame
# Out:
#            coefficient
# HEALTH2       1.063599
# AGE2         -0.327165
# EDUCCAT2      0.239196
# EMPSTAT4      0.181093
# POVERTY2     -0.431431
# x_pca_alc     0.082371
# x_pca_mr      0.157802

# %% [markdown]
# #predictions

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([6.34990821, 4.08536123, 2.73921063, ..., 3.75247941, 5.63115355,
#        1.17488032])

# %% [markdown]
# #test how far off is our prediction from the actual Y (target variable)

# %%
plt.scatter(y_test, predictions)

# %%
sns.distplot(y_test-predictions) #residual histogram
# Out:
# C:\Users\sharl\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #normal distribution implies linear regression is good choice of model

# %% [markdown]
# #regression evaluation metrics

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions) #MAE
# Out:
# 3.149848572597022

# %%
metrics.mean_squared_error(y_test, predictions) #MSE ---this one 'punishes' large erorrs
# Out:
# 17.371351631169663

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions)) #RMSE --- interpreted in 'y' units
# Out:
# 4.167895347914779

# %% [markdown]
# ##Logistic regression???

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions_linear = logmodel.predict(X_test)

# %%
plt.scatter(y_test, predictions_linear)

# %%
##evaluations

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-49b4b26ceb45> in <module>()
# ----> 1 print(classification_report(y_test,predictions))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits)
#    1419
#    1420     if labels is None:
# -> 1421         labels = unique_labels(y_true, y_pred)
#    1422     else:
#    1423         labels = np.asarray(labels)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in unique_labels(*ys)
#      80
#      81     if len(ys_types) > 1:
# ---> 82         raise ValueError("Mix type of y not allowed, got types %s" % ys_types)
#      83
#      84     label_type = ys_types.pop()
#
# ValueError: Mix type of y not allowed, got types {'continuous', 'multiclass'}
