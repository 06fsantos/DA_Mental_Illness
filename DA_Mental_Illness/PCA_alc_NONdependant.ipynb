# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
 
# %matplotlib inline

# %%
df = pd.read_excel("Project_Data_set.xlsx", index_col = None)

# %%
df = df.loc[df['DEPNDALC'] == 0]

# %%
df.head()
# Out:
#    Unnamed: 0  CASEID  HEALTH2  AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  K6SCMON  \
# 0           0       1      2.0    17         3         4       2.0        0
# 1           1       2      2.0     8         3         2       1.0       12
# 2           2       3      3.0    13         2         1       1.0       12
# 3           3       4      3.0    16         2         1       2.0       15
# 4           4       5      2.0    16         4         1       3.0        0
#
#       K6SCYR  K6SCMAX  ...  NODR30A  DR5DAY  MJEVER  MJYRTOT  MRDAYPYR  \
# 0  10.291153        0  ...      0.0     0.0       2      0.0  0.000000
# 1  21.000000       21  ...      5.0     1.0       1    104.0  3.153398
# 2  10.291153       12  ...      0.0     0.0       2      0.0  0.000000
# 3  24.000000       24  ...      2.0     0.0       1      0.0  0.000000
# 4  10.291153        0  ...      0.0     0.0       2      0.0  0.000000
#
#     MRDAYPMO  MRDAYPWK  MJDAY30A  DEPNDALC  DEPNDMRJ
# 0   0.000000       0.0       0.0         0         0
# 1  14.484054       2.0       1.0         0         0
# 2   0.000000       0.0       0.0         0         0
# 3   0.000000       0.0       0.0         0         0
# 4   0.000000       0.0       0.0         0         0
#
# [5 rows x 26 columns]

# %%
df= df[['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4',
       'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCYRTOT',
       'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY',
       'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A',
       'DEPNDALC', 'DEPNDMRJ']]

# %%
df.corr()
# Out:
#             CASEID   HEALTH2      AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  \
# CASEID    1.000000  0.002822 -0.000644 -0.007291  0.002572 -0.012015
# HEALTH2   0.002822  1.000000  0.167197 -0.243523  0.192237 -0.158919
# AGE2     -0.000644  0.167197  1.000000  0.171699 -0.003609  0.217411
# EDUCCAT2 -0.007291 -0.243523  0.171699  1.000000 -0.209810  0.360059
# EMPSTAT4  0.002572  0.192237 -0.003609 -0.209810  1.000000 -0.266380
# POVERTY2 -0.012015 -0.158919  0.217411  0.360059 -0.266380  1.000000
# K6SCMON   0.002022  0.208283 -0.184778 -0.075107  0.102907 -0.154304
# K6SCYR    0.003601  0.098841 -0.122428 -0.075866  0.053882 -0.097035
# K6SCMAX   0.004428  0.175435 -0.192129 -0.032466  0.075815 -0.126732
# ALCYRTOT  0.002543 -0.089887  0.100852  0.170001 -0.127889  0.142875
# ALDAYPYR -0.005956 -0.027441  0.048325  0.050857 -0.035266  0.061133
# ALDAYPMO -0.002058 -0.031551 -0.030643  0.044966 -0.057957  0.025519
# ALDAYPWK -0.010528 -0.026087 -0.079239  0.064982 -0.094164  0.041179
# ALCDAYS   0.001522 -0.095786  0.103659  0.184532 -0.120961  0.152493
# NODR30A   0.012121  0.022858 -0.011519 -0.059298 -0.007475 -0.042332
# DR5DAY    0.004048 -0.007064 -0.049933 -0.010930 -0.076026  0.013783
# MJYRTOT  -0.005445  0.041617 -0.157077 -0.078623 -0.008099 -0.071531
# MRDAYPYR -0.002257  0.016661 -0.053720 -0.038877 -0.004488 -0.014336
# MRDAYPMO  0.010189 -0.016332 -0.175193  0.010687 -0.016688 -0.028820
# MRDAYPWK  0.001930 -0.001660 -0.227879 -0.020374 -0.017466 -0.064097
# MJDAY30A -0.000752  0.044835 -0.135132 -0.073173 -0.010662 -0.064414
# DEPNDALC       NaN       NaN       NaN       NaN       NaN       NaN
# DEPNDMRJ  0.001867  0.015772 -0.091796 -0.026754  0.001727 -0.033626
#
#            K6SCMON    K6SCYR   K6SCMAX  ALCYRTOT  ...   ALCDAYS   NODR30A  \
# CASEID    0.002022  0.003601  0.004428  0.002543  ...  0.001522  0.012121
# HEALTH2   0.208283  0.098841  0.175435 -0.089887  ... -0.095786  0.022858
# AGE2     -0.184778 -0.122428 -0.192129  0.100852  ...  0.103659 -0.011519
# EDUCCAT2 -0.075107 -0.075866 -0.032466  0.170001  ...  0.184532 -0.059298
# EMPSTAT4  0.102907  0.053882  0.075815 -0.127889  ... -0.120961 -0.007475
# POVERTY2 -0.154304 -0.097035 -0.126732  0.142875  ...  0.152493 -0.042332
# K6SCMON   1.000000  0.421502  0.866937 -0.043724  ... -0.045757  0.022230
# K6SCYR    0.421502  1.000000  0.561331 -0.034490  ... -0.034089  0.012314
# K6SCMAX   0.866937  0.561331  1.000000 -0.040392  ... -0.037908  0.011142
# ALCYRTOT -0.043724 -0.034490 -0.040392  1.000000  ...  0.816284  0.020246
# ALDAYPYR -0.024044 -0.005208 -0.019881  0.294689  ...  0.288984  0.015576
# ALDAYPMO  0.009468 -0.002915  0.009198  0.321568  ...  0.172809  0.014782
# ALDAYPWK  0.027362  0.023033  0.049615 -0.116626  ... -0.103607  0.052198
# ALCDAYS  -0.045757 -0.034089 -0.037908  0.816284  ...  1.000000 -0.010886
# NODR30A   0.022230  0.012314  0.011142  0.020246  ... -0.010886  1.000000
# DR5DAY   -0.002808  0.010913 -0.005119  0.444529  ...  0.525767  0.128108
# MJYRTOT   0.099788  0.064738  0.095584  0.125273  ...  0.115791  0.026861
# MRDAYPYR  0.038302  0.024851  0.033590  0.046001  ...  0.040392  0.011166
# MRDAYPMO  0.097508  0.065172  0.112795  0.119890  ...  0.120538  0.013993
# MRDAYPWK  0.118668  0.080839  0.133282  0.155316  ...  0.152565  0.020409
# MJDAY30A  0.092081  0.057937  0.088904  0.113430  ...  0.118286  0.023455
# DEPNDALC       NaN       NaN       NaN       NaN  ...       NaN       NaN
# DEPNDMRJ  0.095339  0.052804  0.091384  0.026460  ...  0.027221  0.015778
#
#             DR5DAY   MJYRTOT  MRDAYPYR  MRDAYPMO  MRDAYPWK  MJDAY30A  \
# CASEID    0.004048 -0.005445 -0.002257  0.010189  0.001930 -0.000752
# HEALTH2  -0.007064  0.041617  0.016661 -0.016332 -0.001660  0.044835
# AGE2     -0.049933 -0.157077 -0.053720 -0.175193 -0.227879 -0.135132
# EDUCCAT2 -0.010930 -0.078623 -0.038877  0.010687 -0.020374 -0.073173
# EMPSTAT4 -0.076026 -0.008099 -0.004488 -0.016688 -0.017466 -0.010662
# POVERTY2  0.013783 -0.071531 -0.014336 -0.028820 -0.064097 -0.064414
# K6SCMON  -0.002808  0.099788  0.038302  0.097508  0.118668  0.092081
# K6SCYR    0.010913  0.064738  0.024851  0.065172  0.080839  0.057937
# K6SCMAX  -0.005119  0.095584  0.033590  0.112795  0.133282  0.088904
# ALCYRTOT  0.444529  0.125273  0.046001  0.119890  0.155316  0.113430
# ALDAYPYR  0.169671  0.050394  0.066808  0.053340  0.052123  0.050572
# ALDAYPMO  0.095110  0.070310  0.037060  0.059684  0.089547  0.062342
# ALDAYPWK -0.056653  0.053086  0.019679  0.059607  0.074071  0.048678
# ALCDAYS   0.525767  0.115791  0.040392  0.120538  0.152565  0.118286
# NODR30A   0.128108  0.026861  0.011166  0.013993  0.020409  0.023455
# DR5DAY    1.000000  0.172162  0.059091  0.128709  0.182241  0.170283
# MJYRTOT   0.172162  1.000000  0.367555  0.201101  0.449972  0.899413
# MRDAYPYR  0.059091  0.367555  1.000000  0.360384  0.280495  0.359193
# MRDAYPMO  0.128709  0.201101  0.360384  1.000000  0.816299  0.214482
# MRDAYPWK  0.182241  0.449972  0.280495  0.816299  1.000000  0.410702
# MJDAY30A  0.170283  0.899413  0.359193  0.214482  0.410702  1.000000
# DEPNDALC       NaN       NaN       NaN       NaN       NaN       NaN
# DEPNDMRJ  0.040131  0.334693  0.115562  0.088773  0.176318  0.311452
#
#           DEPNDALC  DEPNDMRJ
# CASEID         NaN  0.001867
# HEALTH2        NaN  0.015772
# AGE2           NaN -0.091796
# EDUCCAT2       NaN -0.026754
# EMPSTAT4       NaN  0.001727
# POVERTY2       NaN -0.033626
# K6SCMON        NaN  0.095339
# K6SCYR         NaN  0.052804
# K6SCMAX        NaN  0.091384
# ALCYRTOT       NaN  0.026460
# ALDAYPYR       NaN  0.016264
# ALDAYPMO       NaN  0.022275
# ALDAYPWK       NaN  0.028472
# ALCDAYS        NaN  0.027221
# NODR30A        NaN  0.015778
# DR5DAY         NaN  0.040131
# MJYRTOT        NaN  0.334693
# MRDAYPYR       NaN  0.115562
# MRDAYPMO       NaN  0.088773
# MRDAYPWK       NaN  0.176318
# MJDAY30A       NaN  0.311452
# DEPNDALC       NaN       NaN
# DEPNDMRJ       NaN  1.000000
#
# [23 rows x 23 columns]

# %%
col_names = list(df)
print (col_names)
# Out:
# ['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCEVER', 'ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJEVER', 'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDALC', 'DEPNDMRJ']

# %%
#create df for alcohol, weed and K6 variables

# %%
df_alc= df[['ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY']]
df_mr= df[['MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A']]
df_K6 = df[['K6SCMON', 'K6SCYR', 'K6SCMAX']]

# %%
#PCA visualisation

# %% [markdown]
# PCA is effected by scale so we need to scale the features in our data before applying PCA. Use StandardScaler to help  standardize the dataset’s features onto unit scale (mean = 0 and variance = 1) which is a requirement for the optimal performance of many machine learning algorithms.

# %%
#standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled_data_alc= StandardScaler().fit_transform(df_alc)
scaled_data_mr= StandardScaler().fit_transform(df_mr)
scaled_data_K6= StandardScaler().fit_transform(df_K6)

# %% [markdown]
# scaled_data_alc= df_alc.apply(np.log)
# scaled_data_mr= df_mr.apply(np.log)
# scaled_data_K6= df_K6.apply(np.log)

# %% [markdown]
# scaled_data_alc.head()

# %%
df_alc.shape
# Out:
# (38904, 7)

# %%
df_mr.shape
# Out:
# (38904, 5)

# %%
df_K6.shape
# Out:
# (38904, 3)

# %%
#PCA with Scikit Learn uses a very similar process to other preprocessing functions that come with SciKit Learn. 
#We instantiate a PCA object, find the principal components using the fit method, then apply the rotation and dimensionality reduction by calling transform().
#We can also specify how many components we want to keep when creating the PCA object.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1) #set how many dimensions

# %%
x_pca_alc =pca.fit_transform(scaled_data_alc)
x_pca_mr =pca.fit_transform(scaled_data_mr)
x_pca_K6 =pca.fit_transform(scaled_data_K6)

# %%
#Now we can transform this data to its first principal component.

# %%
scaled_data_alc.shape #shape before
# Out:
# (38904, 7)

# %%
x_pca_alc.shape  #shape after (to check if worked)
# Out:
# (38904, 1)

# %% [markdown]
# We've reduced the 7,5 and 3 dimensions to just 1.

# %%
#Unfortunately, with this great power of dimensionality reduction, comes the cost of being able to easily understand what these components represent.
#The components correspond to combinations of the original features, the components themselves are stored as an attribute of the fitted PCA object:

# %%
df_comp_alc =pd.DataFrame(data=x_pca_alc, columns= ['PCA_alcohol1'])
df_comp_mr =pd.DataFrame(data=x_pca_alc, columns= ['PCA_marijuana'])
df_comp_K6 =pd.DataFrame(data=x_pca_alc, columns= ['PCA K6'])

# %%
#now do regression on PCA data instead of whole df

# %% [markdown]
# ##Regression on PCA

# %%
df.columns
# Out:
# Index(['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2',
#        'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCEVER', 'ALCYRTOT', 'ALDAYPYR',
#        'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJEVER',
#        'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDALC',
#        'DEPNDMRJ'],
#       dtype='object')

# %%
df_PCA =df[['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX']]

# %%
df_PCA=df_PCA.assign(x_pca_alc = x_pca_alc, x_pca_mr=x_pca_mr, x_pca_K6=x_pca_K6)

# %%
df_PCA.describe()
# Out:
#              CASEID       HEALTH2         AGE2      EDUCCAT2      EMPSTAT4  \
# count  38904.000000  38904.000000  38904.00000  38904.000000  38904.000000
# mean   27683.714657      2.250153     13.49689      2.720312      2.021129
# std    15951.616454      0.942729      2.69624      1.015593      1.255936
# min        1.000000      1.000000      7.00000      1.000000      1.000000
# 25%    13865.250000      2.000000     12.00000      2.000000      1.000000
# 50%    27727.500000      2.000000     14.00000      3.000000      1.000000
# 75%    41549.750000      3.000000     15.00000      4.000000      3.000000
# max    55270.000000      4.000000     17.00000      4.000000      4.000000
#
#            POVERTY2       K6SCMON        K6SCYR       K6SCMAX     x_pca_alc  \
# count  38904.000000  38904.000000  38904.000000  38904.000000  3.890400e+04
# mean       2.412744      4.053285     10.179742      5.271335  1.519198e-16
# std        0.783395      4.332760      3.422423      5.629126  1.560422e+00
# min        1.000000      0.000000      0.000000      0.000000 -1.129473e+00
# 25%        2.000000      1.000000     10.291153      1.000000 -1.129473e+00
# 50%        3.000000      3.000000     10.291153      3.000000 -5.765614e-01
# 75%        3.000000      6.000000     10.291153      8.000000  4.928674e-01
# max        3.000000     24.000000     24.000000     24.000000  1.298894e+01
#
#            x_pca_mr      x_pca_K6
# count  3.890400e+04  3.890400e+04
# mean   2.897127e-16  4.592940e-16
# std    1.664402e+00  1.501227e+00
# min   -6.307547e-01 -2.602255e+00
# 25%   -6.307547e-01 -1.140574e+00
# 50%   -6.307547e-01 -3.861785e-01
# 75%   -6.307547e-01  5.131279e-01
# max    1.269175e+01  6.841696e+00

# %%
sns.distplot(df_PCA['x_pca_K6'])
# Out:
# C:\Users\sharl\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(df_PCA) #creates histogram and correlation  scater plots

# %%
df_PCA.corr()
# Out:
#              CASEID   HEALTH2      AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  \
# CASEID     1.000000  0.002822 -0.000644 -0.007291  0.002572 -0.012015
# HEALTH2    0.002822  1.000000  0.167197 -0.243523  0.192237 -0.158919
# AGE2      -0.000644  0.167197  1.000000  0.171699 -0.003609  0.217411
# EDUCCAT2  -0.007291 -0.243523  0.171699  1.000000 -0.209810  0.360059
# EMPSTAT4   0.002572  0.192237 -0.003609 -0.209810  1.000000 -0.266380
# POVERTY2  -0.012015 -0.158919  0.217411  0.360059 -0.266380  1.000000
# K6SCMON    0.002022  0.208283 -0.184778 -0.075107  0.102907 -0.154304
# K6SCYR     0.003601  0.098841 -0.122428 -0.075866  0.053882 -0.097035
# K6SCMAX    0.004428  0.175435 -0.192129 -0.032466  0.075815 -0.126732
# x_pca_alc  0.001635 -0.079594  0.065481  0.142003 -0.128782  0.126755
# x_pca_mr   0.000761  0.024313 -0.205910 -0.055950 -0.015595 -0.068404
# x_pca_K6   0.003846  0.189552 -0.194815 -0.068376  0.090701 -0.146770
#
#             K6SCMON    K6SCYR   K6SCMAX  x_pca_alc  x_pca_mr  x_pca_K6
# CASEID     0.002022  0.003601  0.004428   0.001635  0.000761  0.003846
# HEALTH2    0.208283  0.098841  0.175435  -0.079594  0.024313  0.189552
# AGE2      -0.184778 -0.122428 -0.192129   0.065481 -0.205910 -0.194815
# EDUCCAT2  -0.075107 -0.075866 -0.032466   0.142003 -0.055950 -0.068376
# EMPSTAT4   0.102907  0.053882  0.075815  -0.128782 -0.015595  0.090701
# POVERTY2  -0.154304 -0.097035 -0.126732   0.126755 -0.068404 -0.146770
# K6SCMON    1.000000  0.421502  0.866937  -0.036233  0.122574  0.903296
# K6SCYR     0.421502  1.000000  0.561331  -0.023258  0.080585  0.729722
# K6SCMAX    0.866937  0.561331  1.000000  -0.032392  0.127391  0.951414
# x_pca_alc -0.036233 -0.023258 -0.032392   1.000000  0.195601 -0.035729
# x_pca_mr   0.122574  0.080585  0.127391   0.195601  1.000000  0.129004
# x_pca_K6   0.903296  0.729722  0.951414  -0.035729  0.129004  1.000000

# %%
sns.heatmap(df_PCA.corr(), annot=True)

# %%
df_PCA.columns
# Out:
# Index(['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2',
#        'K6SCMON', 'K6SCYR', 'K6SCMAX', 'x_pca_alc', 'x_pca_mr', 'x_pca_K6'],
#       dtype='object')

# %% [markdown]
# Training a linear reg model with scikit.
# Split the data into features to train on (x array) and target variable(y).

# %%
X = df_PCA[['HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'x_pca_alc', 'x_pca_mr']] #education and employment is non linear, maybe better logistic regression

# %%
y = df_PCA['K6SCMON']

# %%
from sklearn.model_selection  import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101) #40% test, #random split seed 101

# %% [markdown]
# create and train the model

# %%
from sklearn.linear_model import LinearRegression #import a reg model

# %%
lm = LinearRegression()  #initiate and instance of regression model

# %%
lm.fit(X_train, y_train) #train/fit my model on training data
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#evaluate the model, check it's coefficient and see how can be interpreted

# %%
print(lm.intercept_)  #print the intercept
# Out:
# 6.126018258362411

# %%
lm.coef_ #grab the coefficience for each feautre
# Out:
# array([ 1.05211165, -0.32543086,  0.23626351,  0.17069464, -0.426233  ,
#        -0.03133748,  0.20309298])

# %%
X_train.columns
# Out:
# Index(['HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'x_pca_alc',
#        'x_pca_mr'],
#       dtype='object')

# %%
cdf = pd.DataFrame(lm.coef_,X_train.columns, columns=['coefficient'])

# %%
cdf #cdf as coefficient dataFrame
# Out:
#            coefficient
# HEALTH2       1.052112
# AGE2         -0.325431
# EDUCCAT2      0.236264
# EMPSTAT4      0.170695
# POVERTY2     -0.426233
# x_pca_alc    -0.031337
# x_pca_mr      0.203093

# %% [markdown]
# #predictions

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([4.19267805, 3.01730222, 4.97980157, ..., 3.64237625, 3.85766448,
#        2.65600971])

# %% [markdown]
# #test how far off is our prediction from the actual Y (target variable)

# %%
plt.scatter(y_test, predictions)

# %%
sns.distplot(y_test-predictions) #residual histogram
# Out:
# C:\Users\sharl\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #normal distribution implies linear regression is good choice of model

# %% [markdown]
# #regression evaluation metrics

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions) #MAE
# Out:
# 3.0444322459716657

# %%
metrics.mean_squared_error(y_test, predictions) #MSE ---this one 'punishes' large erorrs
# Out:
# 16.12405269516252

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions)) #RMSE --- interpreted in 'y' units
# Out:
# 4.015476646073604

# %% [markdown]
# ##Logistic regression???

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions_linear = logmodel.predict(X_test)

# %%
plt.scatter(y_test, predictions_linear)

# %%
##evaluations

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-49b4b26ceb45> in <module>()
# ----> 1 print(classification_report(y_test,predictions))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits)
#    1419
#    1420     if labels is None:
# -> 1421         labels = unique_labels(y_true, y_pred)
#    1422     else:
#    1423         labels = np.asarray(labels)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in unique_labels(*ys)
#      80
#      81     if len(ys_types) > 1:
# ---> 82         raise ValueError("Mix type of y not allowed, got types %s" % ys_types)
#      83
#      84     label_type = ys_types.pop()
#
# ValueError: Mix type of y not allowed, got types {'continuous', 'multiclass'}
