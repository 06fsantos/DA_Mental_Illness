# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
 
# %matplotlib inline

# %%
df = pd.read_excel("Project_Data_set.xlsx", index_col = None)

# %%
df = df.loc[df['DEPNDMRJ'] == 1]

# %%
df.head()
# Out:
#      Unnamed: 0  CASEID  HEALTH2  AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  K6SCMON  \
# 188         272     273      2.0    10         1         4       3.0        6
# 690         956     957      2.0    12         4         1       3.0       17
# 729        1009    1010      2.0     8         3         2       3.0        4
# 836        1159    1160      4.0    14         3         3       2.0       19
# 858        1191    1192      4.0    12         3         2       3.0       15
#
#         K6SCYR  K6SCMAX  ...  ALCDAYS  NODR30A  DR5DAY  MJYRTOT    MRDAYPYR  \
# 188  18.000000       18  ...      5.0      6.0     5.0     24.0   24.000000
# 690  10.291153       17  ...     22.0      3.0     9.0    200.0  200.000000
# 729  10.000000       10  ...      5.0      3.0     0.0    360.0    3.153398
# 836  17.000000       19  ...      4.0      2.0     0.0    260.0    3.153398
# 858  24.000000       24  ...     20.0      4.0     2.0    312.0    3.153398
#
#       MRDAYPMO  MRDAYPWK  MJDAY30A  DEPNDALC  DEPNDMRJ
# 188  99.000000  0.358722       0.0         1         1
# 690  99.000000  0.358722       9.0         1         1
# 729   0.383745  7.000000      25.0         0         1
# 836   0.383745  5.000000      20.0         0         1
# 858   0.383745  6.000000       1.0         0         1
#
# [5 rows x 24 columns]

# %%
df= df[['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4',
       'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCYRTOT',
       'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY',
       'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A',
       'DEPNDALC']]

# %%
df.corr()
# Out:
#             CASEID   HEALTH2      AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  \
# CASEID    1.000000 -0.016124  0.000106  0.003717 -0.025468  0.019107
# HEALTH2  -0.016124  1.000000  0.118934 -0.150870  0.158290 -0.003054
# AGE2      0.000106  0.118934  1.000000  0.244934 -0.172065  0.051054
# EDUCCAT2  0.003717 -0.150870  0.244934  1.000000 -0.187334  0.212999
# EMPSTAT4 -0.025468  0.158290 -0.172065 -0.187334  1.000000 -0.277966
# POVERTY2  0.019107 -0.003054  0.051054  0.212999 -0.277966  1.000000
# K6SCMON   0.048012  0.307970 -0.047558 -0.085728  0.144662 -0.061111
# K6SCYR   -0.029882  0.147269 -0.048661 -0.034467  0.087403  0.004752
# K6SCMAX   0.019846  0.247080 -0.027894 -0.019993  0.107314  0.006695
# ALCYRTOT -0.028389 -0.021606  0.125858  0.136519 -0.076010  0.023687
# ALDAYPYR  0.006654 -0.011713  0.134554  0.069293 -0.030981  0.046999
# ALDAYPMO -0.046685  0.040792 -0.042836 -0.047784  0.064808 -0.038778
# ALDAYPWK -0.002289 -0.024802  0.060270  0.142370 -0.085287  0.057482
# ALCDAYS  -0.062495 -0.046736  0.137491  0.239701 -0.099221  0.091680
# NODR30A   0.012167  0.027319 -0.117109  0.017016  0.098249  0.036486
# DR5DAY   -0.078822 -0.075199  0.021439  0.123242  0.046772  0.019352
# MJYRTOT  -0.046371  0.077996  0.001994  0.067705 -0.032954 -0.037061
# MRDAYPYR -0.040221  0.038499  0.043787 -0.002379 -0.028347  0.066257
# MRDAYPMO  0.006791 -0.007690 -0.001481 -0.079670  0.037322  0.065418
# MRDAYPWK -0.002734  0.068978 -0.040269  0.046892 -0.004304 -0.032760
# MJDAY30A  0.031654  0.091992  0.016515 -0.007869 -0.015593 -0.041630
# DEPNDALC -0.031140  0.083105  0.020115 -0.003323  0.015775 -0.047562
#
#            K6SCMON    K6SCYR   K6SCMAX  ALCYRTOT  ...  ALDAYPWK   ALCDAYS  \
# CASEID    0.048012 -0.029882  0.019846 -0.028389  ... -0.002289 -0.062495
# HEALTH2   0.307970  0.147269  0.247080 -0.021606  ... -0.024802 -0.046736
# AGE2     -0.047558 -0.048661 -0.027894  0.125858  ...  0.060270  0.137491
# EDUCCAT2 -0.085728 -0.034467 -0.019993  0.136519  ...  0.142370  0.239701
# EMPSTAT4  0.144662  0.087403  0.107314 -0.076010  ... -0.085287 -0.099221
# POVERTY2 -0.061111  0.004752  0.006695  0.023687  ...  0.057482  0.091680
# K6SCMON   1.000000  0.515863  0.842100  0.046488  ...  0.009960 -0.002597
# K6SCYR    0.515863  1.000000  0.750639  0.014836  ... -0.006484 -0.013866
# K6SCMAX   0.842100  0.750639  1.000000  0.014549  ...  0.001890 -0.026514
# ALCYRTOT  0.046488  0.014836  0.014549  1.000000  ...  0.841413  0.687102
# ALDAYPYR -0.025340 -0.046070 -0.046793  0.210213  ... -0.033731  0.176773
# ALDAYPMO  0.109994  0.116801  0.097274  0.313817  ... -0.054255  0.089502
# ALDAYPWK  0.009960 -0.006484  0.001890  0.841413  ...  1.000000  0.620634
# ALCDAYS  -0.002597 -0.013866 -0.026514  0.687102  ...  0.620634  1.000000
# NODR30A   0.069748  0.030891  0.046388  0.245815  ...  0.151876  0.215375
# DR5DAY   -0.067720 -0.042409 -0.078275  0.532663  ...  0.447459  0.635327
# MJYRTOT   0.049033  0.025000  0.054971  0.028982  ...  0.069671  0.060192
# MRDAYPYR  0.086124  0.015333  0.052283  0.007808  ...  0.027123 -0.045271
# MRDAYPMO  0.051280  0.003867  0.027034 -0.058810  ... -0.045612 -0.106457
# MRDAYPWK  0.006683  0.029646  0.014469  0.033528  ...  0.052238  0.078888
# MJDAY30A -0.008537 -0.034075 -0.016937 -0.072919  ... -0.017804  0.058014
# DEPNDALC  0.164305  0.054315  0.117282  0.409124  ...  0.390984  0.318552
#
#            NODR30A    DR5DAY   MJYRTOT  MRDAYPYR  MRDAYPMO  MRDAYPWK  \
# CASEID    0.012167 -0.078822 -0.046371 -0.040221  0.006791 -0.002734
# HEALTH2   0.027319 -0.075199  0.077996  0.038499 -0.007690  0.068978
# AGE2     -0.117109  0.021439  0.001994  0.043787 -0.001481 -0.040269
# EDUCCAT2  0.017016  0.123242  0.067705 -0.002379 -0.079670  0.046892
# EMPSTAT4  0.098249  0.046772 -0.032954 -0.028347  0.037322 -0.004304
# POVERTY2  0.036486  0.019352 -0.037061  0.066257  0.065418 -0.032760
# K6SCMON   0.069748 -0.067720  0.049033  0.086124  0.051280  0.006683
# K6SCYR    0.030891 -0.042409  0.025000  0.015333  0.003867  0.029646
# K6SCMAX   0.046388 -0.078275  0.054971  0.052283  0.027034  0.014469
# ALCYRTOT  0.245815  0.532663  0.028982  0.007808 -0.058810  0.033528
# ALDAYPYR  0.081646  0.240456 -0.056972  0.017008  0.051064 -0.035041
# ALDAYPMO  0.242249  0.076407  0.016665 -0.028367 -0.065987  0.036888
# ALDAYPWK  0.151876  0.447459  0.069671  0.027123 -0.045612  0.052238
# ALCDAYS   0.215375  0.635327  0.060192 -0.045271 -0.106457  0.078888
# NODR30A   1.000000  0.388593  0.087372 -0.069437 -0.075787  0.144271
# DR5DAY    0.388593  1.000000  0.012269 -0.084801 -0.111994  0.054095
# MJYRTOT   0.087372  0.012269  1.000000  0.137563 -0.220138  0.698365
# MRDAYPYR -0.069437 -0.084801  0.137563  1.000000  0.755764 -0.377073
# MRDAYPMO -0.075787 -0.111994 -0.220138  0.755764  1.000000 -0.498930
# MRDAYPWK  0.144271  0.054095  0.698365 -0.377073 -0.498930  1.000000
# MJDAY30A  0.033735  0.040587  0.631395  0.139617 -0.026166  0.463934
# DEPNDALC  0.228789  0.317293 -0.079724 -0.055281 -0.066991 -0.022256
#
#           MJDAY30A  DEPNDALC
# CASEID    0.031654 -0.031140
# HEALTH2   0.091992  0.083105
# AGE2      0.016515  0.020115
# EDUCCAT2 -0.007869 -0.003323
# EMPSTAT4 -0.015593  0.015775
# POVERTY2 -0.041630 -0.047562
# K6SCMON  -0.008537  0.164305
# K6SCYR   -0.034075  0.054315
# K6SCMAX  -0.016937  0.117282
# ALCYRTOT -0.072919  0.409124
# ALDAYPYR -0.049348  0.059197
# ALDAYPMO -0.058541  0.055280
# ALDAYPWK -0.017804  0.390984
# ALCDAYS   0.058014  0.318552
# NODR30A   0.033735  0.228789
# DR5DAY    0.040587  0.317293
# MJYRTOT   0.631395 -0.079724
# MRDAYPYR  0.139617 -0.055281
# MRDAYPMO -0.026166 -0.066991
# MRDAYPWK  0.463934 -0.022256
# MJDAY30A  1.000000 -0.116102
# DEPNDALC -0.116102  1.000000
#
# [22 rows x 22 columns]

# %%
col_names = list(df)
print (col_names)
# Out:
# ['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDALC']

# %%
#create df for alcohol, weed and K6 variables

# %%
df_alc= df[['ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY']]
df_mr= df[['MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A']]
df_K6 = df[['K6SCMON', 'K6SCYR', 'K6SCMAX']]

# %%
#PCA visualisation

# %% [markdown]
# PCA is effected by scale so we need to scale the features in our data before applying PCA. Use StandardScaler to help  standardize the dataset’s features onto unit scale (mean = 0 and variance = 1) which is a requirement for the optimal performance of many machine learning algorithms.

# %%
#standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled_data_alc= StandardScaler().fit_transform(df_alc)
scaled_data_mr= StandardScaler().fit_transform(df_mr)
scaled_data_K6= StandardScaler().fit_transform(df_K6)

# %% [markdown]
# scaled_data_alc= df_alc.apply(np.log)
# scaled_data_mr= df_mr.apply(np.log)
# scaled_data_K6= df_K6.apply(np.log)

# %% [markdown]
# scaled_data_alc.head()

# %%
df_alc.shape
# Out:
# (536, 7)

# %%
df_mr.shape
# Out:
# (536, 5)

# %%
df_K6.shape
# Out:
# (536, 3)

# %%
#PCA with Scikit Learn uses a very similar process to other preprocessing functions that come with SciKit Learn. 
#We instantiate a PCA object, find the principal components using the fit method, then apply the rotation and dimensionality reduction by calling transform().
#We can also specify how many components we want to keep when creating the PCA object.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1) #set how many dimensions

# %%
x_pca_alc =pca.fit_transform(scaled_data_alc)
x_pca_mr =pca.fit_transform(scaled_data_mr)
x_pca_K6 =pca.fit_transform(scaled_data_K6)

# %%
#Now we can transform this data to its first principal component.

# %%
scaled_data_alc.shape #shape before
# Out:
# (536, 7)

# %%
x_pca_alc.shape  #shape after (to check if worked)
# Out:
# (536, 1)

# %% [markdown]
# We've reduced the 7,5 and 3 dimensions to just 1.

# %%
#Unfortunately, with this great power of dimensionality reduction, comes the cost of being able to easily understand what these components represent.
#The components correspond to combinations of the original features, the components themselves are stored as an attribute of the fitted PCA object:

# %%
df_comp_alc =pd.DataFrame(data=x_pca_alc, columns= ['PCA_alcohol1'])
df_comp_mr =pd.DataFrame(data=x_pca_alc, columns= ['PCA_marijuana'])
df_comp_K6 =pd.DataFrame(data=x_pca_alc, columns= ['PCA K6'])

# %%
#now do regression on PCA data instead of whole df

# %% [markdown]
# ##Regression on PCA

# %%
df.columns
# Out:
# Index(['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2',
#        'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO',
#        'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJYRTOT', 'MRDAYPYR',
#        'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDALC'],
#       dtype='object')

# %%
df_PCA =df[['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX']]

# %%
df_PCA=df_PCA.assign(x_pca_alc = x_pca_alc, x_pca_mr=x_pca_mr, x_pca_K6=x_pca_K6)

# %%
df_PCA.describe()
# Out:
#              CASEID     HEALTH2        AGE2    EDUCCAT2    EMPSTAT4  \
# count    536.000000  536.000000  536.000000  536.000000  536.000000
# mean   27722.194030    2.427239   11.188433    2.462687    2.050373
# std    15967.984651    0.912184    2.495592    0.936541    1.145197
# min      273.000000    1.000000    7.000000    1.000000    1.000000
# 25%    14361.250000    2.000000    9.000000    2.000000    1.000000
# 50%    27424.000000    2.000000   11.000000    2.000000    2.000000
# 75%    41367.750000    3.000000   13.000000    3.000000    3.000000
# max    55230.000000    4.000000   17.000000    4.000000    4.000000
#
#          POVERTY2     K6SCMON      K6SCYR     K6SCMAX     x_pca_alc  \
# count  536.000000  536.000000  536.000000  536.000000  5.360000e+02
# mean     2.145161    8.389925   12.001235   10.494403  2.827340e-17
# std      0.832102    5.533839    4.462471    6.549878  1.760821e+00
# min      1.000000    0.000000    1.000000    0.000000 -2.385726e+00
# 25%      1.000000    4.000000   10.291153    5.000000 -1.248217e+00
# 50%      2.000000    8.000000   10.291153   10.000000 -4.393183e-01
# 75%      3.000000   12.000000   13.250000   16.000000  8.388797e-01
# max      3.000000   24.000000   24.000000   24.000000  7.353806e+00
#
#            x_pca_mr      x_pca_K6
# count  5.360000e+02  5.360000e+02
# mean   4.101197e-17 -1.669477e-16
# std    1.565741e+00  1.555211e+00
# min   -1.906095e+00 -3.092982e+00
# 25%   -1.407460e+00 -1.275618e+00
# 50%   -2.802274e-01 -2.860809e-01
# 75%    1.236897e+00  1.061610e+00
# max    3.253511e+00  4.336542e+00

# %%
sns.distplot(df_PCA['x_pca_K6'])
# Out:
# C:\Users\sharl\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(df_PCA) #creates histogram and correlation  scater plots

# %%
df_PCA.corr()
# Out:
#              CASEID   HEALTH2      AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  \
# CASEID     1.000000 -0.016124  0.000106  0.003717 -0.025468  0.019107
# HEALTH2   -0.016124  1.000000  0.118934 -0.150870  0.158290 -0.003054
# AGE2       0.000106  0.118934  1.000000  0.244934 -0.172065  0.051054
# EDUCCAT2   0.003717 -0.150870  0.244934  1.000000 -0.187334  0.212999
# EMPSTAT4  -0.025468  0.158290 -0.172065 -0.187334  1.000000 -0.277966
# POVERTY2   0.019107 -0.003054  0.051054  0.212999 -0.277966  1.000000
# K6SCMON    0.048012  0.307970 -0.047558 -0.085728  0.144662 -0.061111
# K6SCYR    -0.029882  0.147269 -0.048661 -0.034467  0.087403  0.004752
# K6SCMAX    0.019846  0.247080 -0.027894 -0.019993  0.107314  0.006695
# x_pca_alc -0.047011 -0.038605  0.087125  0.178135 -0.043921  0.057928
# x_pca_mr   0.001982 -0.066986  0.018360 -0.059353  0.020636  0.064728
# x_pca_K6   0.015152  0.262595 -0.045407 -0.051263  0.126149 -0.017987
#
#             K6SCMON    K6SCYR   K6SCMAX  x_pca_alc  x_pca_mr  x_pca_K6
# CASEID     0.048012 -0.029882  0.019846  -0.047011  0.001982  0.015152
# HEALTH2    0.307970  0.147269  0.247080  -0.038605 -0.066986  0.262595
# AGE2      -0.047558 -0.048661 -0.027894   0.087125  0.018360 -0.045407
# EDUCCAT2  -0.085728 -0.034467 -0.019993   0.178135 -0.059353 -0.051263
# EMPSTAT4   0.144662  0.087403  0.107314  -0.043921  0.020636  0.126149
# POVERTY2  -0.061111  0.004752  0.006695   0.057928  0.064728 -0.017987
# K6SCMON    1.000000  0.515863  0.842100   0.014258  0.015136  0.881682
# K6SCYR     0.515863  1.000000  0.750639  -0.002656 -0.006580  0.835779
# K6SCMAX    0.842100  0.750639  1.000000  -0.012363 -0.000820  0.968649
# x_pca_alc  0.014258 -0.002656 -0.012363   1.000000 -0.079444 -0.000673
# x_pca_mr   0.015136 -0.006580 -0.000820  -0.079444  1.000000  0.002921
# x_pca_K6   0.881682  0.835779  0.968649  -0.000673  0.002921  1.000000

# %%
sns.heatmap(df_PCA.corr(), annot=True)

# %%
df_PCA.columns
# Out:
# Index(['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2',
#        'K6SCMON', 'K6SCYR', 'K6SCMAX', 'x_pca_alc', 'x_pca_mr', 'x_pca_K6'],
#       dtype='object')

# %% [markdown]
# Training a linear reg model with scikit.
# Split the data into features to train on (x array) and target variable(y).

# %%
X = df_PCA[['HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'x_pca_alc', 'x_pca_mr']] #education and employment is non linear, maybe better logistic regression

# %%
y = df_PCA['K6SCMON']

# %%
from sklearn.model_selection  import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101) #40% test, #random split seed 101

# %% [markdown]
# create and train the model

# %%
from sklearn.linear_model import LinearRegression #import a reg model

# %%
lm = LinearRegression()  #initiate and instance of regression model

# %%
lm.fit(X_train, y_train) #train/fit my model on training data
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#evaluate the model, check it's coefficient and see how can be interpreted

# %%
print(lm.intercept_)  #print the intercept
# Out:
# 4.765847160528901

# %%
lm.coef_ #grab the coefficience for each feautre
# Out:
# array([ 1.83044374, -0.12960821,  0.101519  ,  0.54126165, -0.37253851,
#         0.06897595,  0.22053574])

# %%
X_train.columns
# Out:
# Index(['HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'x_pca_alc',
#        'x_pca_mr'],
#       dtype='object')

# %%
cdf = pd.DataFrame(lm.coef_,X_train.columns, columns=['coefficient'])

# %%
cdf #cdf as coefficient dataFrame
# Out:
#            coefficient
# HEALTH2       1.830444
# AGE2         -0.129608
# EDUCCAT2      0.101519
# EMPSTAT4      0.541262
# POVERTY2     -0.372539
# x_pca_alc     0.068976
# x_pca_mr      0.220536

# %% [markdown]
# #predictions

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([12.14210088,  9.48769244, 11.40645347,  9.41467055,  5.81579391,
#         8.52523368,  6.00164671,  7.13047568,  8.44891247, 10.21848799,
#         9.93313531,  7.63300099,  9.69382414,  8.47128471,  6.23035906,
#         7.13125067,  8.75058243,  4.32462549,  7.19043057,  6.31174348,
#         5.17410052,  6.125914  , 10.46352043,  9.9897559 ,  9.32830335,
#        10.3028006 ,  8.96284738, 11.07583416,  5.45220272,  8.4893161 ,
#         6.20754933,  8.71035048,  6.65232979,  6.61802244,  4.90550702,
#         8.59469899, 10.70447683, 10.7237657 , 13.12984301, 11.68445087,
#         5.98730888, 11.10770537,  6.96362597,  9.46986278, 10.20666979,
#         9.49540123,  6.18721121,  7.21508958,  4.12364618,  7.27951922,
#         6.38644478,  8.2904218 ,  8.11305925,  6.56984757,  6.54779306,
#        10.67318196,  8.06023017,  9.92028698,  8.78879186,  8.19830626,
#         5.26402068,  4.68438933,  7.661604  , 11.59289509,  9.16959639,
#         6.94184091,  7.66065747, 10.33688568, 12.61399195,  6.93350707,
#         6.32058157, 10.04401445,  6.04270722,  8.25288274,  9.7135483 ,
#         9.22013023, 10.19978284,  5.38363925,  8.37590467,  6.41567496,
#         6.86417708, 11.44807291,  8.71503657,  7.37642692,  7.54762633,
#        12.09422842,  9.61850221,  7.29217354, 12.34787831,  8.0947488 ,
#         6.73805092,  6.27054405,  6.37310995, 10.9171189 , 10.55495895,
#         9.68360117, 10.19074973,  6.92016245, 12.33687177,  9.50679769,
#        12.56050333,  9.11386158, 11.12603603,  9.82931897,  7.90346235,
#        10.25792128,  6.98589001,  7.56556032,  6.35811347,  4.74691211,
#         7.85281062,  8.72308133,  9.28515171,  8.98672224,  9.05078499,
#         9.65027876,  6.65786182,  7.33120688, 10.13365726,  8.79709699,
#         7.21296163,  8.02960685,  8.68602146,  8.81723125,  7.58319271,
#        10.57379189,  8.50591166,  8.58386905,  8.97326736,  5.69131044,
#         7.36386244,  7.98049568,  9.47381373,  8.01315383,  6.90567001,
#         6.62390985, 11.51770442,  5.0686628 ,  8.83024687,  5.1776794 ,
#         7.69468283, 10.03694007, 10.25209362,  6.6192259 ,  6.68080508,
#         9.26490215,  8.94408567,  8.7265375 , 11.26955913,  6.48860176,
#         7.18713073,  8.14245124,  4.99789062,  6.05029421,  9.19465482,
#         7.73736341,  9.47369492, 11.63799245,  5.52467995, 12.05604624,
#         6.90635263, 12.45083836, 10.19015635,  8.7268589 ,  8.13296213,
#         8.16492209,  7.7649297 , 11.86842273,  6.07267679,  6.21424962,
#         7.24330816, 10.73960395,  5.12235919,  7.62286564, 12.07765818,
#         8.74473425,  6.7845225 ,  7.50985953,  8.85502329, 10.47969044,
#         5.44575738,  6.30542625, 10.42430444,  9.05413322,  5.90093237,
#         8.00550499,  7.0667679 ,  7.12276615,  8.79600403,  8.91596866,
#        10.01885195, 10.32100946, 10.37132436,  6.50168678,  8.00730147,
#        10.51597523,  5.14644501,  7.02021139,  5.3330634 , 10.14251408,
#         7.08483809,  6.63682295,  9.46383109,  6.60270721,  7.66213757,
#         7.63821175,  5.08212343,  9.21951932,  5.16853405,  6.98110933,
#         9.28767928,  6.35116995,  4.9979354 ,  8.40457937,  7.10727103])

# %% [markdown]
# #test how far off is our prediction from the actual Y (target variable)

# %%
plt.scatter(y_test, predictions)

# %%
sns.distplot(y_test-predictions) #residual histogram
# Out:
# C:\Users\sharl\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #normal distribution implies linear regression is good choice of model

# %% [markdown]
# #regression evaluation metrics

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions) #MAE
# Out:
# 4.320705435893686

# %%
metrics.mean_squared_error(y_test, predictions) #MSE ---this one 'punishes' large erorrs
# Out:
# 28.097183428122566

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions)) #RMSE --- interpreted in 'y' units
# Out:
# 5.300677638578162

# %% [markdown]
# ##Logistic regression???

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions_linear = logmodel.predict(X_test)

# %%
plt.scatter(y_test, predictions_linear)

# %%
##evaluations

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-49b4b26ceb45> in <module>()
# ----> 1 print(classification_report(y_test,predictions))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits)
#    1419
#    1420     if labels is None:
# -> 1421         labels = unique_labels(y_true, y_pred)
#    1422     else:
#    1423         labels = np.asarray(labels)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in unique_labels(*ys)
#      80
#      81     if len(ys_types) > 1:
# ---> 82         raise ValueError("Mix type of y not allowed, got types %s" % ys_types)
#      83
#      84     label_type = ys_types.pop()
#
# ValueError: Mix type of y not allowed, got types {'multiclass', 'continuous'}
