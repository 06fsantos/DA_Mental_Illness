# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
 
# %matplotlib inline

# %%
df = pd.read_excel("Project_Data_set.xlsx", index_col = None)

# %%
df = df.loc[df['DEPNDMRJ'] == 1]

# %%
df.head()
# Out:
#      Unnamed: 0  CASEID  HEALTH2  AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  K6SCMON  \
# 188         272     273      2.0    10         1         4       3.0        6
# 690         956     957      2.0    12         4         1       3.0       17
# 729        1009    1010      2.0     8         3         2       3.0        4
# 836        1159    1160      4.0    14         3         3       2.0       19
# 858        1191    1192      4.0    12         3         2       3.0       15
#
#         K6SCYR  K6SCMAX  ...  NODR30A  DR5DAY  MJEVER  MJYRTOT    MRDAYPYR  \
# 188  18.000000       18  ...      6.0     5.0       1     24.0   24.000000
# 690  10.291153       17  ...      3.0     9.0       1    200.0  200.000000
# 729  10.000000       10  ...      3.0     0.0       1    360.0    3.153398
# 836  17.000000       19  ...      2.0     0.0       1    260.0    3.153398
# 858  24.000000       24  ...      4.0     2.0       1    312.0    3.153398
#
#       MRDAYPMO   MRDAYPWK  MJDAY30A  DEPNDALC  DEPNDMRJ
# 188  99.000000  11.833289       0.0         1         1
# 690  99.000000  11.833289       9.0         1         1
# 729  14.484054   7.000000      25.0         0         1
# 836  14.484054   5.000000      20.0         0         1
# 858  14.484054   6.000000       1.0         0         1
#
# [5 rows x 26 columns]

# %%
df= df[['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4',
       'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCYRTOT',
       'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY',
       'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A',
       'DEPNDALC']]

# %%
df.corr()
# Out:
#             CASEID   HEALTH2      AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  \
# CASEID    1.000000 -0.016124  0.000106  0.003717 -0.025468  0.019107
# HEALTH2  -0.016124  1.000000  0.118934 -0.150870  0.158290 -0.003054
# AGE2      0.000106  0.118934  1.000000  0.244934 -0.172065  0.051054
# EDUCCAT2  0.003717 -0.150870  0.244934  1.000000 -0.187334  0.212999
# EMPSTAT4 -0.025468  0.158290 -0.172065 -0.187334  1.000000 -0.277966
# POVERTY2  0.019107 -0.003054  0.051054  0.212999 -0.277966  1.000000
# K6SCMON   0.048012  0.307970 -0.047558 -0.085728  0.144662 -0.061111
# K6SCYR   -0.029882  0.147269 -0.048661 -0.034467  0.087403  0.004752
# K6SCMAX   0.019846  0.247080 -0.027894 -0.019993  0.107314  0.006695
# ALCYRTOT -0.028389 -0.021606  0.125858  0.136519 -0.076010  0.023687
# ALDAYPYR  0.006654 -0.011713  0.134554  0.069293 -0.030981  0.046999
# ALDAYPMO -0.043170  0.064611 -0.062648 -0.083986  0.072766 -0.065012
# ALDAYPWK  0.000973  0.094052 -0.157788 -0.104536  0.093169 -0.005790
# ALCDAYS  -0.063105 -0.045560  0.135716  0.239127 -0.099311  0.092273
# NODR30A  -0.062820  0.077305 -0.080204 -0.135855  0.047590 -0.015432
# DR5DAY   -0.080018 -0.070586  0.017090  0.118792  0.047150  0.021620
# MJYRTOT  -0.046371  0.077996  0.001994  0.067705 -0.032954 -0.037061
# MRDAYPYR -0.040221  0.038499  0.043787 -0.002379 -0.028347  0.066257
# EMPSTAT4  0.047590  0.047150 -0.032954 -0.028347  0.037322  0.001965
# POVERTY2 -0.015432  0.021620 -0.037061  0.066257  0.065418  0.060482
# K6SCMON   0.059562 -0.062578  0.049033  0.086124  0.051280 -0.024134
# K6SCYR    0.017147 -0.040183  0.025000  0.015333  0.003867 -0.022997
# K6SCMAX   0.032818 -0.073839  0.054971  0.052283  0.027034 -0.016850
# ALCYRTOT -0.014322  0.533706  0.028982  0.007808 -0.058810 -0.090369
# ALDAYPYR -0.016252  0.239876 -0.056972  0.017008  0.051064 -0.029437
# ALDAYPMO  0.102008 -0.008613 -0.008394 -0.032488 -0.057165 -0.033697
# ALDAYPWK  0.052080 -0.232188  0.000264  0.014890  0.036929  0.061548
# ALCDAYS  -0.087604  0.635485  0.060063 -0.045698 -0.107037 -0.091275
# NODR30A   1.000000  0.065436 -0.016899  0.101451  0.088418  0.100150
# DR5DAY    0.065436  1.000000  0.011395 -0.086835 -0.114686 -0.086848
# MJYRTOT  -0.016899  0.011395  1.000000  0.137563 -0.220138 -0.131587
# MRDAYPYR  0.101451 -0.086835  0.137563  1.000000  0.755764  0.400332
# MRDAYPMO  0.088418 -0.114686 -0.220138  0.755764  1.000000  0.529705
# MRDAYPWK  0.100150 -0.086848 -0.131587  0.400332  0.529705  1.000000
# MJDAY30A  0.013317  0.035507  0.631633  0.139526 -0.026508 -0.086172
# DEPNDALC  0.059096  0.318089 -0.079724 -0.055281 -0.066991 -0.120707
#
#           MJDAY30A  DEPNDALC
# CASEID    0.031402 -0.031140
# HEALTH2   0.092289  0.083105
# AGE2      0.015592  0.020115
# EDUCCAT2 -0.008254 -0.003323
# EMPSTAT4 -0.015717  0.015775
# POVERTY2 -0.041603 -0.047562
# K6SCMON  -0.008003  0.164305
# K6SCYR   -0.033664  0.054315
# K6SCMAX  -0.016469  0.117282
# ALCYRTOT -0.073157  0.409124
# ALDAYPYR -0.049500  0.059197
# ALDAYPMO -0.042585 -0.003132
# ALDAYPWK  0.029866 -0.198844
# ALCDAYS   0.056164  0.318013
# NODR30A   0.013317  0.059096
# DR5DAY    0.035507  0.318089
# MJYRTOT   0.631633 -0.079724
# MRDAYPYR  0.139526 -0.055281
# MRDAYPMO -0.026508 -0.066991
# MRDAYPWK -0.086172 -0.120707
# MJDAY30A  1.000000 -0.116380
# DEPNDALC -0.116380  1.000000
#
# [22 rows x 22 columns]

# %%
col_names = list(df)
print (col_names)
# Out:
# ['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCEVER', 'ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJEVER', 'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDALC', 'DEPNDMRJ']

# %%
#create df for alcohol, weed and K6 variables

# %%
df_alc= df[['ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY']]
df_mr= df[['MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A']]
df_K6 = df[['K6SCMON', 'K6SCYR', 'K6SCMAX']]

# %%
#PCA visualisation

# %% [markdown]
# PCA is effected by scale so we need to scale the features in our data before applying PCA. Use StandardScaler to help  standardize the dataset’s features onto unit scale (mean = 0 and variance = 1) which is a requirement for the optimal performance of many machine learning algorithms.

# %%
#standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled_data_alc= StandardScaler().fit_transform(df_alc)
scaled_data_mr= StandardScaler().fit_transform(df_mr)
scaled_data_K6= StandardScaler().fit_transform(df_K6)

# %% [markdown]
# scaled_data_alc= df_alc.apply(np.log)
# scaled_data_mr= df_mr.apply(np.log)
# scaled_data_K6= df_K6.apply(np.log)

# %% [markdown]
# scaled_data_alc.head()

# %%
df_alc.shape
# Out:
# (536, 7)

# %%
df_mr.shape
# Out:
# (536, 5)

# %%
df_K6.shape
# Out:
# (536, 3)

# %%
#PCA with Scikit Learn uses a very similar process to other preprocessing functions that come with SciKit Learn. 
#We instantiate a PCA object, find the principal components using the fit method, then apply the rotation and dimensionality reduction by calling transform().
#We can also specify how many components we want to keep when creating the PCA object.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1) #set how many dimensions

# %%
x_pca_alc =pca.fit_transform(scaled_data_alc)
x_pca_mr =pca.fit_transform(scaled_data_mr)
x_pca_K6 =pca.fit_transform(scaled_data_K6)

# %%
#Now we can transform this data to its first principal component.

# %%
scaled_data_alc.shape #shape before
# Out:
# (536, 7)

# %%
x_pca_alc.shape  #shape after (to check if worked)
# Out:
# (536, 1)

# %% [markdown]
# We've reduced the 7,5 and 3 dimensions to just 1.

# %%
#Unfortunately, with this great power of dimensionality reduction, comes the cost of being able to easily understand what these components represent.
#The components correspond to combinations of the original features, the components themselves are stored as an attribute of the fitted PCA object:

# %%
df_comp_alc =pd.DataFrame(data=x_pca_alc, columns= ['PCA_alcohol1'])
df_comp_mr =pd.DataFrame(data=x_pca_alc, columns= ['PCA_marijuana'])
df_comp_K6 =pd.DataFrame(data=x_pca_alc, columns= ['PCA K6'])

# %%
#now do regression on PCA data instead of whole df

# %% [markdown]
# ##Regression on PCA

# %%
df.columns
# Out:
# Index(['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2',
#        'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCEVER', 'ALCYRTOT', 'ALDAYPYR',
#        'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJEVER',
#        'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDALC',
#        'DEPNDMRJ'],
#       dtype='object')

# %%
df_PCA =df[['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX']]

# %%
df_PCA=df_PCA.assign(x_pca_alc = x_pca_alc, x_pca_mr=x_pca_mr, x_pca_K6=x_pca_K6)

# %%
df_PCA.describe()
# Out:
#              CASEID     HEALTH2        AGE2    EDUCCAT2    EMPSTAT4  \
# count    536.000000  536.000000  536.000000  536.000000  536.000000
# mean   27722.194030    2.427239   11.188433    2.462687    2.050373
# std    15967.984651    0.912184    2.495592    0.936541    1.145197
# min      273.000000    1.000000    7.000000    1.000000    1.000000
# 25%    14361.250000    2.000000    9.000000    2.000000    1.000000
# 50%    27424.000000    2.000000   11.000000    2.000000    2.000000
# 75%    41367.750000    3.000000   13.000000    3.000000    3.000000
# max    55230.000000    4.000000   17.000000    4.000000    4.000000
#
#          POVERTY2     K6SCMON      K6SCYR     K6SCMAX     x_pca_alc  \
# count  536.000000  536.000000  536.000000  536.000000  5.360000e+02
# mean     2.145161    8.389925   12.001235   10.494403  2.794329e-17
# std      0.832102    5.533839    4.462471    6.549878  1.592910e+00
# min      1.000000    0.000000    1.000000    0.000000 -1.757383e+00
columns
# Out:
# Index(['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2',
#        'K6SCMON', 'K6SCYR', 'K6SCMAX', 'x_pca_alc', 'x_pca_mr', 'x_pca_K6'],
#       dtype='object')

# %% [markdown]
# Training a linear reg model with scikit.
# Split the data into features to train on (x array) and target variable(y).

# %%
X = df_PCA[['HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'x_pca_alc', 'x_pca_mr']] #education and employment is non linear, maybe better logistic regression

# %%
y = df_PCA['K6SCMON']

# %%
from sklearn.model_selection  import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101) #40% test, #random split seed 101

# %% [markdown]
# create and train the model

# %%
from sklearn.linear_model import LinearRegression #import a reg model

# %%
lm = LinearRegression()  #initiate and instance of regression model

# %%
lm.fit(X_train, y_train) #train/fit my model on training data
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#evaluate the model, check it's coefficient and see how can be interpreted

# %%
print(lm.intercept_)  #print the intercept
# Out:
# 4.709395454880182

# %%
lm.coef_ #grab the coefficience for each feautre
# Out:
# array([ 1.79736088, -0.12214182,  0.08036085,  0.54901628, -0.33435798,
#         0.03791935,  0.05943866])

# %%
X_train.columns
# Out:
# Index(['HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'x_pca_alc',
#        'x_pca_mr'],
#       dtype='object')

# %%
cdf = pd.DataFrame(lm.coef_,X_train.columns, columns=['coefficient'])

# %%
cdf #cdf as coefficient dataFrame
# Out:
#            coefficient
# HEALTH2       1.797361
# AGE2         -0.122142
# EDUCCAT2      0.080361
# EMPSTAT4      0.549016
# POVERTY2     -0.334358
# x_pca_alc     0.037919
# x_pca_mr      0.059439

# %% [markdown]
# #predictions

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([12.07975566,  9.25093909, 10.87759337,  9.2238526 ,  6.04881022,
#         8.34611901,  6.10683644,  7.29466897,  7.85216451,  9.84998661,
#        10.13088181,  7.76299059,  9.74312759,  8.16153913,  6.63730303,
#         6.77790856,  9.11159179,  4.75831266,  7.27922826,  6.70509914,
#         5.35564928,  6.32312111,  9.97479153,  9.33585569,  9.37142838,
#        10.66303754,  9.31532008, 10.88071192,  5.64293663,  8.29009989,
#         6.65277868,  8.51858283,  6.90753894,  6.6114745 ,  4.77266748,
#         8.82861573, 10.75593173, 10.75337026, 12.97273756, 11.99585193,
#         6.14814575, 10.8843012 ,  6.50386046,  9.38929162, 10.50161836,
#         9.27178577,  6.59622509,  7.57769604,  4.58728499,  7.68039686,
#         6.51460756,  8.09849814,  8.01424208,  6.67317947,  6.58472159,
#        10.74257153,  8.234224  , 10.08999167,  9.19857695,  8.60778948,
#         4.87737017,  5.09972803,  7.34304199, 11.76349765,  9.24590534,
#         6.72423704,  7.33695044,  9.92676879, 12.30744422,  6.50108954,
#         6.54978275,  9.52456435,  5.54296141,  8.51334492,  9.36163248,
#         9.33914231,  9.92391854,  4.98723246,  7.99283397,  6.46521944,
#         7.24119939, 11.75868205,  8.28252177,  7.23128774,  7.70652818,
#        12.06573196,  9.91692016,  7.69574639, 12.10456151,  8.00971272,
#         6.34000633,  6.29166772,  6.19270342, 10.45378999, 10.31420579,
#         9.52136259,  9.56408529,  6.98743141, 11.79632373,  9.68850849,
#        12.18614803,  8.92217256, 10.62319513,  9.57020369,  8.12655332,
#        10.61738678,  6.71335237,  7.90898034,  6.0556159 ,  4.96893125,
#         7.46177684,  9.02353437,  9.73832878,  8.82566588,  9.21417154,
#         9.59682546,  6.70696583,  7.42683438, 10.24102917,  8.42864542,
#         7.15271542,  8.39344972,  8.63552458,  8.59479583,  7.26821748,
#        10.8041156 ,  8.24875546,  8.63721282,  8.70011098,  6.15769885,
#         6.84100335,  7.49649037,  8.98193837,  7.57368886,  6.52794199,
#         7.0499786 , 11.61317437,  5.44647024,  8.56139317,  5.64825654,
#         8.06648593,  9.73238668,  9.86934052,  6.39876903,  7.12457973,
#         9.1959641 ,  8.90410607,  9.07197096, 10.77793233,  6.37183811,
#         7.50005463,  8.6171219 ,  5.17159311,  6.14628816,  8.86690428,
#         7.8739638 ,  9.43981387, 11.62309693,  5.83186817, 11.80841594,
#         6.78555873, 12.20962618,  9.92901032,  8.72580309,  8.43081889,
#         8.33587881,  7.66784133, 12.22459475,  6.350145  ,  6.5484002 ,
#         7.47580664, 10.7470276 ,  4.8569777 ,  7.02000093, 12.26156127,
#         9.08605123,  7.04433739,  7.70134084,  9.21238597, 10.47386036,
#         5.31876715,  6.62856573, 10.75605992,  9.36759867,  5.62438079,
#         7.88992815,  6.89117564,  7.13488461,  8.5427863 ,  9.0087615 ,
#         9.89535489, 10.03564682, 10.21795497,  6.53656589,  7.98299924,
#        10.79459666,  4.86427078,  7.40668798,  5.0579722 , 10.16097175,
#         7.4933769 ,  6.80409818,  9.24151108,  6.89543931,  7.39872848,
#         7.33087785,  4.76528584,  8.94633033,  5.0256455 ,  6.69915581,
#         9.62806666,  6.11238754,  5.04499814,  7.94146363,  7.19430755])

# %% [markdown]
# #test how far off is our prediction from the actual Y (target variable)

# %%
plt.scatter(y_test, predictions)

# %%
sns.distplot(y_test-predictions) #residual histogram
# Out:
# C:\Users\sharl\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #normal distribution implies linear regression is good choice of model

# %% [markdown]
# #regression evaluation metrics

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions) #MAE
# Out:
# 4.305578949995499

# %%
metrics.mean_squared_error(y_test, predictions) #MSE ---this one 'punishes' large erorrs
# Out:
# 27.973628585557105

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions)) #RMSE --- interpreted in 'y' units
# Out:
# 5.289010170680059

# %% [markdown]
# ##Logistic regression???

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions_linear = logmodel.predict(X_test)

# %%
plt.scatter(y_test, predictions_linear)

# %%
##evaluations

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-49b4b26ceb45> in <module>()
# ----> 1 print(classification_report(y_test,predictions))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits)
#    1419
#    1420     if labels is None:
# -> 1421         labels = unique_labels(y_true, y_pred)
#    1422     else:
#    1423         labels = np.asarray(labels)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in unique_labels(*ys)
#      80
#      81     if len(ys_types) > 1:
# ---> 82         raise ValueError("Mix type of y not allowed, got types %s" % ys_types)
#      83
#      84     label_type = ys_types.pop()
#
# ValueError: Mix type of y not allowed, got types {'continuous', 'multiclass'}
