# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
 
# %matplotlib inline

# %%
df = pd.read_excel("Project_Data_set.xlsx", index_col = None)

# %%
df = df.loc[df['DEPNDALC'] == 1]

# %%
df.head()
# Out:
#      Unnamed: 0  CASEID  HEALTH2  AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  K6SCMON  \
# 11           16      17      3.0    13         1         1       2.0        3
# 31           50      51      2.0    11         2         1       2.0       12
# 106         153     154      2.0    11         2         1       2.0       17
# 111         161     162      1.0    16         2         4       3.0        4
# 121         172     173      3.0    15         2         1       2.0       15
#
#         K6SCYR  K6SCMAX  ...  ALCDAYS  NODR30A    DR5DAY  MJYRTOT  MRDAYPYR  \
# 11    6.000000        6  ...      5.0      5.0  1.273094      0.0  0.000000
# 31   18.000000       18  ...      7.0      2.0  0.000000      0.0  0.000000
# 106  17.000000       17  ...      8.0      3.0  2.000000     48.0  3.153398
# 111   4.000000        4  ...     25.0      4.0  3.000000      0.0  0.000000
# 121  10.291153       15  ...      6.0      6.0  6.000000      0.0  0.000000
#
#      MRDAYPMO  MRDAYPWK  MJDAY30A  DEPNDALC  DEPNDMRJ
# 11   0.000000  0.000000       0.0         1         0
# 31   0.000000  0.000000       0.0         1         0
# 106  0.383745  0.358722      15.0         1         0
# 111  0.000000  0.000000       0.0         1         0
# 121  0.000000  0.000000       0.0         1         0
#
# [5 rows x 24 columns]

# %%
df= df[['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4',
       'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCYRTOT',
       'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY',
       'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A',
       'DEPNDMRJ']]

# %%
df.corr()
# Out:
#             CASEID   HEALTH2      AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  \
# CASEID    1.000000 -0.003273 -0.033780  0.004288  0.003298  0.001548
# HEALTH2  -0.003273  1.000000  0.219869 -0.245132  0.132174 -0.157466
# AGE2     -0.033780  0.219869  1.000000  0.101695 -0.029095  0.138264
# EDUCCAT2  0.004288 -0.245132  0.101695  1.000000 -0.189356  0.271920
# EMPSTAT4  0.003298  0.132174 -0.029095 -0.189356  1.000000 -0.330299
# POVERTY2  0.001548 -0.157466  0.138264  0.271920 -0.330299  1.000000
# K6SCMON  -0.031518  0.234099 -0.131746 -0.113428  0.139758 -0.155652
# K6SCYR   -0.011395  0.122853 -0.154027 -0.102430  0.123828 -0.092714
# K6SCMAX  -0.017387  0.170585 -0.154953 -0.061512  0.126215 -0.105436
# ALCYRTOT -0.003185  0.066551  0.237971  0.036792 -0.060038  0.126193
# ALDAYPYR  0.004135  0.056517  0.070535 -0.005798 -0.030819  0.023952
# ALDAYPMO  0.021278  0.020446 -0.001468 -0.071575  0.080517 -0.041836
# ALDAYPWK -0.017635  0.040337  0.197233  0.058638 -0.081840  0.119256
# ALCDAYS   0.005367  0.016724  0.199554  0.063464 -0.089262  0.123505
# NODR30A  -0.003684  0.057922 -0.056113 -0.115173  0.043338 -0.033739
# K6SCMON   0.001330 -0.020115  0.090368  0.011294  0.030121  0.104099
# K6SCYR   -0.032131 -0.040752  0.038735  0.017518  0.063133  0.035277
# K6SCMAX  -0.034739 -0.063152  0.057494  0.012252  0.055328  0.064681
# ALCYRTOT  0.096632  0.430130  0.098263  0.028229 -0.022782  0.076523
# ALDAYPYR  0.022936  0.172797  0.037061  0.115523  0.059954 -0.029891
# ALDAYPMO  0.084060  0.006354  0.004794  0.027231  0.022162 -0.027304
# ALDAYPWK  0.033221  0.328797  0.078063 -0.031521 -0.051182  0.099111
# ALCDAYS   0.138935  0.628044  0.121052  0.011554 -0.026657  0.098590
# NODR30A   1.000000  0.291239  0.034124  0.009210  0.005295  0.041934
# DR5DAY    0.291239  1.000000  0.126556  0.014060 -0.014191  0.105943
# MJYRTOT   0.034124  0.126556  1.000000  0.340104 -0.053716  0.859988
# MRDAYPYR  0.009210  0.014060  0.340104  1.000000  0.372090 -0.027147
# MRDAYPMO  0.005295 -0.014191 -0.053716  0.372090  1.000000 -0.125023
# MRDAYPWK  0.041934  0.105943  0.859988 -0.027147 -0.125023  1.000000
# MJDAY30A  0.053525  0.145995  0.870034  0.304054 -0.032909  0.748103
# DEPNDMRJ -0.003647 -0.025927  0.392125  0.068688 -0.044251  0.370437
#
#           MJDAY30A  DEPNDMRJ
# CASEID    0.006724 -0.010705
# HEALTH2   0.087677  0.045396
# AGE2     -0.164152 -0.154945
# EDUCCAT2 -0.064793 -0.047026
# EMPSTAT4 -0.012215  0.031119
# POVERTY2 -0.077172 -0.069716
# K6SCMON   0.049551  0.120552
# K6SCYR    0.017835  0.044027
# K6SCMAX   0.016984  0.087313
# ALCYRTOT  0.088085  0.010783
# ALDAYPYR  0.029272 -0.010623
# ALDAYPMO -0.008715 -0.017672
# ALDAYPWK  0.075371  0.028506
# ALCDAYS   0.156726 -0.018830
# NODR30A   0.053525 -0.003647
# DR5DAY    0.145995 -0.025927
# MJYRTOT   0.870034  0.392125
# MRDAYPYR  0.304054  0.068688
# MRDAYPMO -0.032909 -0.044251
# MRDAYPWK  0.748103  0.370437
# MJDAY30A  1.000000  0.314820
# DEPNDMRJ  0.314820  1.000000
#
# [22 rows x 22 columns]

# %%
col_names = list(df)
print (col_names)
# Out:
# ['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDMRJ']

# %%
#create df for alcohol, weed and K6 variables

# %%
df_alc= df[['ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY']]
df_mr= df[['MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A']]
df_K6 = df[['K6SCMON', 'K6SCYR', 'K6SCMAX']]

# %%
#PCA visualisation

# %% [markdown]
# PCA is effected by scale so we need to scale the features in our data before applying PCA. Use StandardScaler to help  standardize the dataset’s features onto unit scale (mean = 0 and variance = 1) which is a requirement for the optimal performance of many machine learning algorithms.

# %%
#standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled_data_alc= StandardScaler().fit_transform(df_alc)
scaled_data_mr= StandardScaler().fit_transform(df_mr)
scaled_data_K6= StandardScaler().fit_transform(df_K6)

# %% [markdown]
# scaled_data_alc= df_alc.apply(np.log)
# scaled_data_mr= df_mr.apply(np.log)
# scaled_data_K6= df_K6.apply(np.log)

# %% [markdown]
# scaled_data_alc.head()

# %%
df_alc.shape
# Out:
# (1524, 7)

# %%
df_mr.shape
# Out:
# (1524, 5)

# %%
df_K6.shape
# Out:
# (1524, 3)

# %%
#PCA with Scikit Learn uses a very similar process to other preprocessing functions that come with SciKit Learn. 
#We instantiate a PCA object, find the principal components using the fit method, then apply the rotation and dimensionality reduction by calling transform().
#We can also specify how many components we want to keep when creating the PCA object.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1) #set how many dimensions

# %%
x_pca_alc =pca.fit_transform(scaled_data_alc)
x_pca_mr =pca.fit_transform(scaled_data_mr)
x_pca_K6 =pca.fit_transform(scaled_data_K6)

# %%
#Now we can transform this data to its first principal component.

# %%
scaled_data_alc.shape #shape before
# Out:
# (1524, 7)

# %%
x_pca_alc.shape  #shape after (to check if worked)
# Out:
# (1524, 1)

# %% [markdown]
# We've reduced the 7,5 and 3 dimensions to just 1.

# %%
#Unfortunately, with this great power of dimensionality reduction, comes the cost of being able to easily understand what these components represent.
#The components correspond to combinations of the original features, the components themselves are stored as an attribute of the fitted PCA object:

# %%
df_comp_alc =pd.DataFrame(data=x_pca_alc, columns= ['PCA_alcohol1'])
df_comp_mr =pd.DataFrame(data=x_pca_alc, columns= ['PCA_marijuana'])
df_comp_K6 =pd.DataFrame(data=x_pca_alc, columns= ['PCA K6'])

# %%
#now do regression on PCA data instead of whole df

# %% [markdown]
# ##Regression on PCA

# %%
df.columns
# Out:
# Index(['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2',
#        'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO',
#        'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJYRTOT', 'MRDAYPYR',
#        'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDMRJ'],
#       dtype='object')

# %%
df_PCA =df[['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX']]

# %%
df_PCA=df_PCA.assign(x_pca_alc = x_pca_alc, x_pca_mr=x_pca_mr, x_pca_K6=x_pca_K6)

# %%
df_PCA.describe()
# Out:
#              CASEID      HEALTH2         AGE2     EDUCCAT2     EMPSTAT4  \
# count   1524.000000  1524.000000  1524.000000  1524.000000  1524.000000
# mean   27341.620079     2.426509    12.742126     2.630577     1.952100
# std    16051.177904     0.925586     2.521823     0.998033     1.170749
# min       17.000000     1.000000     7.000000     1.000000     1.000000
# 25%    12970.000000     2.000000    11.000000     2.000000     1.000000
# 50%    27149.500000     2.000000    13.000000     3.000000     1.000000
# x_pca_alc -0.004810 -0.066641 -0.054583   1.000000  0.136375 -0.046670
# x_pca_mr   0.084093  0.032648  0.048104   0.136375  1.000000  0.061074
# x_pca_K6   0.882427  0.844385  0.968128  -0.046670  0.061074  1.000000

# %%
sns.heatmap(df_PCA.corr(), annot=True)

# %%
df_PCA.columns
# Out:
# Index(['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2',
#        'K6SCMON', 'K6SCYR', 'K6SCMAX', 'x_pca_alc', 'x_pca_mr', 'x_pca_K6'],
#       dtype='object')

# %% [markdown]
# Training a linear reg model with scikit.
# Split the data into features to train on (x array) and target variable(y).

# %%
X = df_PCA[['HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'x_pca_alc', 'x_pca_mr']] #education and employment is non linear, maybe better logistic regression

# %%
y = df_PCA['K6SCMON']

# %%
from sklearn.model_selection  import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101) #40% test, #random split seed 101

# %% [markdown]
# create and train the model

# %%
from sklearn.linear_model import LinearRegression #import a reg model

# %%
lm = LinearRegression()  #initiate and instance of regression model

# %%
lm.fit(X_train, y_train) #train/fit my model on training data
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#evaluate the model, check it's coefficient and see how can be interpreted

# %%
print(lm.intercept_)  #print the intercept
# Out:
# 9.937365996367333

# %%
lm.coef_ #grab the coefficience for each feautre
# Out:
# array([ 1.64252289, -0.43034082, -0.12970815,  0.35000522, -0.42849683,
#         0.2396051 , -0.00426306])

# %%
X_train.columns
# Out:
# Index(['HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'x_pca_alc',
#        'x_pca_mr'],
#       dtype='object')

# %%
cdf = pd.DataFrame(lm.coef_,X_train.columns, columns=['coefficient'])

# %%
cdf #cdf as coefficient dataFrame
# Out:
#            coefficient
# HEALTH2       1.642523
# AGE2         -0.430341
# EDUCCAT2     -0.129708
# EMPSTAT4      0.350005
# POVERTY2     -0.428497
# x_pca_alc     0.239605
# x_pca_mr     -0.004263

# %% [markdown]
# #predictions

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([ 7.77422549, 10.58796465,  7.29543755,  6.31841267,  7.48709347,
#        10.27357575,  3.24862477,  4.94443202,  6.70929635,  7.9142117 ,
#         7.07398706,  8.57521618,  7.75276626,  7.55768142,  9.53316054,
#         7.41954154,  6.05011437,  9.92921153,  6.02378962, 10.66989014,
#         8.70126785,  7.08468756,  8.06648428,  9.46579064,  7.22693681,
#        10.05761228,  5.44264508,  9.15107754,  6.15138366,  7.33023314,
#         5.64396247,  8.74559172,  5.45587534,  7.53801695,  8.4438072 ,
#         5.81032705,  9.76616982,  8.06006264,  7.71892558,  8.38683984,
#         9.37355259,  8.58146678,  5.7943164 ,  9.38973126,  9.04662848,
#         9.25144987,  6.25470403,  3.57332017, 11.32494298,  8.51164967,
#         8.20482278,  6.59558363,  7.19364263,  4.07072978,  8.4690027 ,
#         8.46875678, 10.49432572,  6.12091897,  3.73760939,  7.48789636,
#         4.47357349,  5.47320776,  4.93106463,  4.31802918,  7.11099978,
#         7.11433286,  5.63774967,  6.97248902,  6.01169418,  9.32889871,
#         6.39426858,  6.55708763,  7.20096171,  7.01562286,  7.74503369,
#         7.23338677,  8.96475182,  7.52285798,  7.52192878,  3.57287873,
#         9.85931215,  5.69331642,  8.83690559,  5.8739852 ,  5.00388652,
#         5.4557736 ,  7.22797458, 11.47837568,  6.83626807, 10.2850429 ,
#         7.22673092, 10.38475494,  8.17948335, 12.02560626, 11.49772095,
#         7.72197593,  8.19011489,  8.86458836,  5.28624143,  6.39247745,
#         5.67072742,  8.08103765, 12.37864669,  6.26792152,  7.68414137,
#         6.65267274,  8.32347479, 11.59994829,  8.82805605,  5.03615019,
#         7.91881489, 10.08906405, 10.17280615,  5.31747119,  5.61678943,
#         6.85486825,  5.54346426,  6.36089703, 10.95831578,  6.10303076,
#         7.48339971, 10.01953873,  8.20262902,  6.25252387,  5.40945655,
#         6.65125884,  5.21133285,  9.0964388 , 11.07203065,  6.20644851,
#         6.31949617,  7.27828424,  7.64335587, 10.34029431,  6.84346483,
#         6.53098207,  7.74500813,  9.46664062,  9.03282214,  8.17264517,
#         7.97529429,  8.21681882, 10.24866571,  6.08712292,  8.29297533,
#         6.17828443, 12.00137673, 12.14791995,  9.10319833,  9.09327544,
#         8.36526228,  5.98307687,  4.41552008, 10.14686577, 10.53403824,
#         7.69333917,  6.2313342 ,  6.99371274,  5.81351066,  6.93445771,
#         7.935665  ,  7.73559127,  8.65271843, 10.57966929,  6.67392886,
#         7.11176605,  9.40150845, 11.3871251 ,  4.51122241,  9.91040607,
#         5.0404804 ,  7.82866682,  8.21520525,  7.52060043, 10.28127548,
#         8.4157449 ,  8.80622458,  6.54556321,  5.63408781,  4.77392849,
#         6.73561725,  5.04676339, 12.05699646,  7.7798339 ,  5.95285211])

# %% [markdown]
# #test how far off is our prediction from the actual Y (target variable)

# %%
plt.scatter(y_test, predictions)

# %%
sns.distplot(y_test-predictions) #residual histogram
# Out:
# C:\Users\sharl\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #normal distribution implies linear regression is good choice of model

# %% [markdown]
# #regression evaluation metrics

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions) #MAE
# Out:
# 4.296923753943519

# %%
metrics.mean_squared_error(y_test, predictions) #MSE ---this one 'punishes' large erorrs
# Out:
# 29.43625081461065

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions)) #RMSE --- interpreted in 'y' units
# Out:
# 5.425518483482537

# %% [markdown]
# ##Logistic regression???

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions_linear = logmodel.predict(X_test)

# %%
plt.scatter(y_test, predictions_linear)

# %%
##evaluations

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-49b4b26ceb45> in <module>()
# ----> 1 print(classification_report(y_test,predictions))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits)
#    1419
#    1420     if labels is None:
# -> 1421         labels = unique_labels(y_true, y_pred)
#    1422     else:
#    1423         labels = np.asarray(labels)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in unique_labels(*ys)
#      80
#      81     if len(ys_types) > 1:
# ---> 82         raise ValueError("Mix type of y not allowed, got types %s" % ys_types)
#      83
#      84     label_type = ys_types.pop()
#
# ValueError: Mix type of y not allowed, got types {'multiclass', 'continuous'}
