# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
 
# %matplotlib inline

# %%
df = pd.read_excel("Project_Data_set.xlsx", index_col = None)

# %%
df = df.loc[df['DEPNDALC'] == 1]

# %%
df.head()
# Out:
#      Unnamed: 0  CASEID  HEALTH2  AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  K6SCMON  \
# 11           16      17      3.0    13         1         1       2.0        3
# 31           50      51      2.0    11         2         1       2.0       12
# 106         153     154      2.0    11         2         1       2.0       17
# 111         161     162      1.0    16         2         4       3.0        4
# 121         172     173      3.0    15         2         1       2.0       15
#
#         K6SCYR  K6SCMAX  ...  NODR30A    DR5DAY  MJEVER  MJYRTOT  MRDAYPYR  \
# 11    6.000000        6  ...      5.0  2.966068       1      0.0  0.000000
# 31   18.000000       18  ...      2.0  0.000000       1      0.0  0.000000
# 106  17.000000       17  ...      3.0  2.000000       1     48.0  3.153398
# 111   4.000000        4  ...      4.0  3.000000       1      0.0  0.000000
# 121  10.291153       15  ...      6.0  6.000000       2      0.0  0.000000
#
#       MRDAYPMO   MRDAYPWK  MJDAY30A  DEPNDALC  DEPNDMRJ
# 11    0.000000   0.000000       0.0         1         0
# 31    0.000000   0.000000       0.0         1         0
# 106  14.484054  11.833289      15.0         1         0
# 111   0.000000   0.000000       0.0         1         0
# 121   0.000000   0.000000       0.0         1         0
#
# [5 rows x 26 columns]

# %%
df= df[['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4',
       'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCYRTOT',
       'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY',
       'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A',
       'DEPNDMRJ']]

# %%
df.corr()
# Out:
#             CASEID   HEALTH2      AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  \
# CASEID    1.000000 -0.003273 -0.033780  0.004288  0.003298  0.001548
# HEALTH2  -0.003273  1.000000  0.219869 -0.245132  0.132174 -0.157466
# AGE2     -0.033780  0.219869  1.000000  0.101695 -0.029095  0.138264
# EDUCCAT2  0.004288 -0.245132  0.101695  1.000000 -0.189356  0.271920
# EMPSTAT4  0.003298  0.132174 -0.029095 -0.189356  1.000000 -0.330299
# POVERTY2  0.001548 -0.157466  0.138264  0.271920 -0.330299  1.000000
# K6SCMON  -0.031518  0.234099 -0.131746 -0.113428  0.139758 -0.155652
# K6SCYR   -0.011395  0.122853 -0.154027 -0.102430  0.123828 -0.092714
# K6SCMAX  -0.017387  0.170585 -0.154953 -0.061512  0.126215 -0.105436
# ALCYRTOT -0.003185  0.066551  0.237971  0.036792 -0.060038  0.126193
# ALDAYPYR  0.004135  0.056517  0.070535 -0.005798 -0.030819  0.023952
# ALDAYPMO  0.023043  0.018670 -0.032113 -0.074411  0.087631 -0.059469
# MJDAY30A  1.000000  0.314901
# DEPNDMRJ  0.314901  1.000000
#
# [23 rows x 23 columns]

# %%
col_names = list(df)
print (col_names)
# Out:
# ['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCEVER', 'ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJEVER', 'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDALC', 'DEPNDMRJ']

# %%
#create df for alcohol, weed and K6 variables

# %%
df_alc= df[['ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY']]
df_mr= df[['MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A']]
df_K6 = df[['K6SCMON', 'K6SCYR', 'K6SCMAX']]

# %%
#PCA visualisation

# %% [markdown]
# PCA is effected by scale so we need to scale the features in our data before applying PCA. Use StandardScaler to help  standardize the dataset’s features onto unit scale (mean = 0 and variance = 1) which is a requirement for the optimal performance of many machine learning algorithms.

# %%
#standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled_data_alc= StandardScaler().fit_transform(df_alc)
scaled_data_mr= StandardScaler().fit_transform(df_mr)
scaled_data_K6= StandardScaler().fit_transform(df_K6)

# %% [markdown]
# scaled_data_alc= df_alc.apply(np.log)
# scaled_data_mr= df_mr.apply(np.log)
# scaled_data_K6= df_K6.apply(np.log)

# %% [markdown]
# scaled_data_alc.head()

# %%
df_alc.shape
# Out:
# (1524, 7)

# %%
df_mr.shape
# Out:
# (1524, 5)

# %%
df_K6.shape
# Out:
# (1524, 3)

# %%
#PCA with Scikit Learn uses a very similar process to other preprocessing functions that come with SciKit Learn. 
#We instantiate a PCA object, find the principal components using the fit method, then apply the rotation and dimensionality reduction by calling transform().
#We can also specify how many components we want to keep when creating the PCA object.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1) #set how many dimensions

# %%
x_pca_alc =pca.fit_transform(scaled_data_alc)
x_pca_mr =pca.fit_transform(scaled_data_mr)
x_pca_K6 =pca.fit_transform(scaled_data_K6)

# %%
#Now we can transform this data to its first principal component.

# %%
scaled_data_alc.shape #shape before
# Out:
# (1524, 7)

# %%
x_pca_alc.shape  #shape after (to check if worked)
# Out:
# (1524, 1)

# %% [markdown]
# We've reduced the 7,5 and 3 dimensions to just 1.

# %%
#Unfortunately, with this great power of dimensionality reduction, comes the cost of being able to easily understand what these components represent.
#The components correspond to combinations of the original features, the components themselves are stored as an attribute of the fitted PCA object:

# %%
df_comp_alc =pd.DataFrame(data=x_pca_alc, columns= ['PCA_alcohol1'])
df_comp_mr =pd.DataFrame(data=x_pca_alc, columns= ['PCA_marijuana'])
df_comp_K6 =pd.DataFrame(data=x_pca_alc, columns= ['PCA K6'])

# %%
#now do regression on PCA data instead of whole df

# %% [markdown]
# ##Regression on PCA

# %%
df.columns
# Out:
# Index(['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2',
#        'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCEVER', 'ALCYRTOT', 'ALDAYPYR',
#        'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJEVER',
#        'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDALC',
#        'DEPNDMRJ'],
#       dtype='object')

# %%
df_PCA =df[['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX']]

# %%
df_PCA=df_PCA.assign(x_pca_alc = x_pca_alc, x_pca_mr=x_pca_mr, x_pca_K6=x_pca_K6)

# %%
df_PCA.describe()
# Out:
#              CASEID      HEALTH2         AGE2     EDUCCAT2     EMPSTAT4  \
# count   1524.000000  1524.000000  1524.000000  1524.000000  1524.000000
# mean   27341.620079     2.426509    12.742126     2.630577     1.952100
# std    16051.177904     0.925586     2.521823     0.998033     1.170749
# min       17.000000     1.000000     7.000000     1.000000     1.000000
# 25%    12970.000000     2.000000    11.000000     2.000000     1.000000
# 50%    27149.500000     2.000000    13.000000     3.000000     1.000000
# 75%    41180.250000     3.000000    15.000000     3.000000     3.000000
# max    55230.000000     4.000000    17.000000     4.000000     4.000000
#
#           POVERTY2      K6SCMON       K6SCYR      K6SCMAX     x_pca_alc  \
# count  1524.000000  1524.000000  1524.000000  1524.000000  1.524000e+03
# mean      2.278353     7.788714    11.748628     9.900262 -1.143734e-17
# std       0.827708     5.504011     4.582305     6.686235  1.534510e+00
# min       1.000000     0.000000     0.000000     0.000000 -2.510430e+00
# 25%       2.000000     4.000000    10.291153     4.000000 -1.211698e+00
# 50%       3.000000     7.000000    10.291153     9.000000 -7.858583e-02
# 75%       3.000000    11.000000    13.000000    15.000000  1.036196e+00
# max       3.000000    24.000000    24.000000    24.000000  4.299462e+00
#
#            x_pca_mr      x_pca_K6
# count  1.524000e+03  1.524000e+03
# mean  -6.818693e-17 -3.861012e-17
# std    1.574702e+00  1.559016e+00
# min   -1.180625e+00 -3.111150e+00
# 25%   -1.180625e+00 -1.306447e+00
# 50%   -1.180625e+00 -3.272433e-01
# 75%    1.020467e+00  1.017815e+00
# max    7.491716e+00  4.427616e+00

# %%
sns.distplot(df_PCA['x_pca_K6'])
# Out:
# C:\Users\sharl\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(df_PCA) #creates histogram and correlation  scater plots

# %%
df_PCA.corr()
# Out:
#              CASEID   HEALTH2      AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  \
# CASEID     1.000000 -0.003273 -0.033780  0.004288  0.003298  0.001548
# HEALTH2   -0.003273  1.000000  0.219869 -0.245132  0.132174 -0.157466
# AGE2      -0.033780  0.219869  1.000000  0.101695 -0.029095  0.138264
# EDUCCAT2   0.004288 -0.245132  0.101695  1.000000 -0.189356  0.271920
# EMPSTAT4   0.003298  0.132174 -0.029095 -0.189356  1.000000 -0.330299
# POVERTY2   0.001548 -0.157466  0.138264  0.271920 -0.330299  1.000000
# K6SCMON   -0.031518  0.234099 -0.131746 -0.113428  0.139758 -0.155652
# K6SCYR    -0.011395  0.122853 -0.154027 -0.102430  0.123828 -0.092714
# K6SCMAX   -0.017387  0.170585 -0.154953 -0.061512  0.126215 -0.105436
# x_pca_alc -0.005597  0.048061  0.217223  0.048294 -0.086472  0.133676
# x_pca_mr  -0.020881  0.047199 -0.238979 -0.011855 -0.004499 -0.060475
# x_pca_K6  -0.022342  0.195748 -0.163169 -0.101334  0.144128 -0.130803
#
#             K6SCMON    K6SCYR   K6SCMAX  x_pca_alc  x_pca_mr  x_pca_K6
# CASEID    -0.031518 -0.011395 -0.017387  -0.005597 -0.020881 -0.022342
# HEALTH2    0.234099  0.122853  0.170585   0.048061  0.047199  0.195748
# AGE2      -0.131746 -0.154027 -0.154953   0.217223 -0.238979 -0.163169
# EDUCCAT2  -0.113428 -0.102430 -0.061512   0.048294 -0.011855 -0.101334
# EMPSTAT4   0.139758  0.123828  0.126215  -0.086472 -0.004499  0.144128
# POVERTY2  -0.155652 -0.092714 -0.105436   0.133676 -0.060475 -0.130803
# K6SCMON    1.000000  0.531593  0.838795  -0.016031  0.075395  0.882427
# K6SCYR     0.531593  1.000000  0.761757  -0.071953  0.068226  0.844385
# K6SCMAX    0.838795  0.761757  1.000000  -0.063651  0.065499  0.968128
# x_pca_alc -0.016031 -0.071953 -0.063651   1.000000  0.092081 -0.056208
# x_pca_mr   0.075395  0.068226  0.065499   0.092081  1.000000  0.077216
# x_pca_K6   0.882427  0.844385  0.968128  -0.056208  0.077216  1.000000

# %%
sns.heatmap(df_PCA.corr(), annot=True)

# %%
df_PCA.columns
# Out:
# Index(['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2',
#        'K6SCMON', 'K6SCYR', 'K6SCMAX', 'x_pca_alc', 'x_pca_mr', 'x_pca_K6'],
#       dtype='object')

# %% [markdown]
# Training a linear reg model with scikit.
# Split the data into features to train on (x array) and target variable(y).

# %%
X = df_PCA[['HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'x_pca_alc', 'x_pca_mr']] #education and employment is non linear, maybe better logistic regression

# %%
y = df_PCA['K6SCMON']

# %%
from sklearn.model_selection  import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101) #40% test, #random split seed 101

# %% [markdown]
# create and train the model

# %%
from sklearn.linear_model import LinearRegression #import a reg model

# %%
lm = LinearRegression()  #initiate and instance of regression model

# %%
lm.fit(X_train, y_train) #train/fit my model on training data
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#evaluate the model, check it's coefficient and see how can be interpreted

# %%
print(lm.intercept_)  #print the intercept
# Out:
# 10.024130744872174

# %%
lm.coef_ #grab the coefficience for each feautre
# Out:
# array([ 1.66417067, -0.44061966, -0.13860657,  0.3521052 , -0.42345091,
#         0.21454038, -0.10025836])

# %%
X_train.columns
# Out:
# Index(['HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'x_pca_alc',
#        'x_pca_mr'],
#       dtype='object')

# %%
cdf = pd.DataFrame(lm.coef_,X_train.columns, columns=['coefficient'])

# %%
cdf #cdf as coefficient dataFrame
# Out:
#            coefficient
# HEALTH2       1.664171
# AGE2         -0.440620
# EDUCCAT2     -0.138607
# EMPSTAT4      0.352105
# POVERTY2     -0.423451
# x_pca_alc     0.214540
# x_pca_mr     -0.100258

# %% [markdown]
# #predictions

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([ 7.98904331, 10.48084858,  7.59718532,  6.40570112,  7.07508594,
#        10.39316423,  3.37617581,  5.10152522,  6.64950391,  7.69787433,
#         7.06412081,  8.60944478,  7.95922807,  7.5506032 ,  9.72035402,
#         7.12141517,  6.23600215,  9.78966101,  5.80580068, 10.56211595,
#         8.78336711,  7.38630479,  7.79247976,  9.16368801,  6.61613591,
#        10.13677557,  5.49838728,  9.32040502,  6.31951887,  7.47755315,
#         5.43446473,  8.82949164,  5.5831096 ,  7.87834385,  8.24817088,
#         5.11389798,  9.89431098,  8.1845904 ,  7.81492742,  8.5053716 ,
#         9.589562  ,  8.63574815,  5.91279384,  9.22627045,  8.95306226,
#         9.33456298,  6.14371554,  3.55788486, 11.27014843,  8.846881  ,
#         8.32740719,  6.94259248,  7.09395865,  3.92088491,  8.47423106,
#         8.44073399, 10.37375215,  6.05254615,  4.04650542,  7.56177905,
#         4.77824469,  5.55334459,  5.1816843 ,  4.38201941,  7.28924167,
#         7.22794798,  5.61494603,  7.14946875,  5.96603341,  9.52907821,
#         6.09006442,  6.44504119,  7.25538577,  6.94372616,  7.76609475,
#         7.6003174 ,  6.95461263,  6.70866983,  8.39004249,  5.44985794,
#        10.12457104,  4.61605652,  6.06640352,  5.17019708,  7.06854081,
#         7.81399102,  6.83840427,  3.8076421 ,  9.75872768, 10.10971368,
#         9.35460583,  5.86923894, 10.34076468,  7.56121249,  7.40966767,
#         8.93651836, 10.10752541,  8.14027932,  6.89491149,  6.9393006 ,
#         6.88712338,  7.2083825 ,  7.63880145, 10.13679407,  9.29143204,
#        11.92955828,  9.45398471,  7.51202592, 10.25237139,  8.73263288,
#         5.64758398,  6.484407  ,  5.18521331,  5.91946685, 10.24889312,
#         7.34738734,  8.57237141, 11.09461514,  5.79999931,  7.73521235,
#         8.2534094 ,  6.62332715,  7.59188602,  7.28726823,  8.79851008,
#         7.17060263,  6.28210353, 11.69699279,  9.43234585,  9.96620373,
#         7.01068076, 10.57176295,  7.96752154, 11.53624887, 11.50263836,
#         7.82175762,  8.39558222,  9.0228092 ,  5.38366032,  6.14284441,
#         5.48226917,  7.9118335 , 12.2075377 ,  6.38635193,  7.90773587,
#         6.48526396,  8.19844122, 11.81875667,  8.93108255,  5.09406693,
#         7.6204837 , 10.23761641, 10.37187438,  5.23853439,  5.66856408,
#         7.17077959,  5.74058418,  6.27966202, 10.84178758,  6.14173267,
#         7.57303379,  9.71286766,  8.09544159,  6.33278819,  5.32599687,
#         6.78071941,  5.44818653,  9.52312862, 11.12037949,  6.32547568,
#         6.33047414,  7.16503118,  7.75291201, 10.21311048,  6.78657967,
#         6.68174199,  7.92246175,  9.29395541,  8.87607906,  8.37977781,
#         7.83292333,  7.9790757 ,  9.68150403,  6.17770578,  8.60675453,
#         5.96273889, 11.76696309, 11.93767599,  8.90533641,  9.23364101,
#         8.25055336,  6.00167467,  4.30200762, 10.01728647, 10.68845886,
#         7.88476247,  6.16241345,  6.62827379,  5.93895421,  6.79774554,
#         7.8897973 ,  8.00002399,  8.70704267, 10.72216362,  6.7800128 ,
#         7.00680598,  9.76053633, 11.18968995,  4.72346951, 10.08273956,
#         4.9720851 ,  7.76817175,  8.36413508,  7.75043074, 10.200233  ,
#         8.49662039,  8.89953044,  6.61485075,  5.78661773,  4.73406362,
#         6.59279923,  5.21523834, 11.67830757,  7.92819351,  5.95954758])

# %% [markdown]
# #test how far off is our prediction from the actual Y (target variable)

# %%
plt.scatter(y_test, predictions)

# %%
sns.distplot(y_test-predictions) #residual histogram
# Out:
# C:\Users\sharl\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #normal distribution implies linear regression is good choice of model

# %% [markdown]
# #regression evaluation metrics

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions) #MAE
# Out:
# 4.298971566586402

# %%
metrics.mean_squared_error(y_test, predictions) #MSE ---this one 'punishes' large erorrs
# Out:
# 29.46951401160279

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions)) #RMSE --- interpreted in 'y' units
# Out:
# 5.4285830574472

# %% [markdown]
# ##Logistic regression???

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions_linear = logmodel.predict(X_test)

# %%
plt.scatter(y_test, predictions_linear)

# %%
##evaluations

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-49b4b26ceb45> in <module>()
# ----> 1 print(classification_report(y_test,predictions))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits)
#    1419
#    1420     if labels is None:
# -> 1421         labels = unique_labels(y_true, y_pred)
#    1422     else:
#    1423         labels = np.asarray(labels)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in unique_labels(*ys)
#      80
#      81     if len(ys_types) > 1:
# ---> 82         raise ValueError("Mix type of y not allowed, got types %s" % ys_types)
#      83
#      84     label_type = ys_types.pop()
#
# ValueError: Mix type of y not allowed, got types {'continuous', 'multiclass'}
