# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
 
# %matplotlib inline

# %%
df = pd.read_excel("Project_Data_set.xlsx", index_col = None)

# %%
df = df.loc[df['K6SCMON'] != 0]

# %%
df.head()
# Out:
#    Unnamed: 0  CASEID  HEALTH2  AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  K6SCMON  \
# 1           1       2      2.0     8         3         2       1.0       12
# 2           2       3      3.0    13         2         1       1.0       12
# 3           3       4      3.0    16         2         1       2.0       15
# 5           8       9      2.0    15         3         3       3.0        6
# 6          10      11      1.0    12         4         1       3.0        2
#
#       K6SCYR  K6SCMAX  ...  ALCDAYS  NODR30A  DR5DAY  MJYRTOT  MRDAYPYR  \
# 1  21.000000       21  ...      1.0      5.0     1.0    104.0  3.153398
# 2  10.291153       12  ...      0.0      0.0     0.0      0.0  0.000000
# 3  24.000000       24  ...      1.0      2.0     0.0      0.0  0.000000
# 5  11.000000       11  ...     12.0      4.0     1.0    260.0  3.153398
# 6  10.291153        2  ...      0.0      0.0     0.0      0.0  0.000000
#
#    MRDAYPMO  MRDAYPWK  MJDAY30A  DEPNDALC  DEPNDMRJ
# 1  0.383745       2.0       1.0         0         0
# 2  0.000000       0.0       0.0         0         0
# 3  0.000000       0.0       0.0         0         0
# 5  0.383745       5.0      24.0         0         0
# 6  0.000000       0.0       0.0         0         0
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4',
#        'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCYRTOT', 'ALDAYPYR',
#        'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJYRTOT',
#        'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDALC', 'DEPNDMRJ'],
#       dtype='object')

# %%
df= df[['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4',
       'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCYRTOT', 'ALDAYPYR',
       'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJYRTOT',
       'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDALC', 'DEPNDMRJ']]

# %%
col_names = list(df)
print (col_names)
# Out:
# ['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDALC', 'DEPNDMRJ']

# %%
df.corr()
# Out:
#             CASEID   HEALTH2      AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  \
# CASEID    1.000000  0.001501 -0.001621 -0.002547  0.001814 -0.010849
# HEALTH2   0.001501  1.000000  0.184055 -0.245700  0.202562 -0.160009
# AGE2     -0.001621  0.184055  1.000000  0.188046 -0.016998  0.213238
# EDUCCAT2 -0.002547 -0.245700  0.188046  1.000000 -0.228488  0.349779
# EMPSTAT4  0.001814  0.202562 -0.016998 -0.228488  1.000000 -0.277977
# POVERTY2 -0.010849 -0.160009  0.213238  0.349779 -0.277977  1.000000
# K6SCMON  -0.000938  0.230009 -0.150303 -0.144880  0.127097 -0.188226
# K6SCYR    0.004392  0.111629 -0.131874 -0.085507  0.061191 -0.105164
# K6SCMAX   0.001652  0.188185 -0.162956 -0.089385  0.093900 -0.151910
# ALCYRTOT  0.003289 -0.075526  0.095130  0.153687 -0.138875  0.121992
# ALDAYPYR -0.001137 -0.020409  0.041753  0.046381 -0.045665  0.048602
# ALDAYPMO  0.001859 -0.053034 -0.016842  0.078402 -0.102627  0.055285
# ALDAYPWK -0.000433 -0.083635  0.072882  0.182687 -0.171590  0.136895
# ALCDAYS   0.001422 -0.082770  0.098041  0.171607 -0.134868  0.133591
# NODR30A  -0.001051 -0.020511 -0.101362 -0.000330 -0.097436  0.016673
# DR5DAY    0.003982  0.005153 -0.045508 -0.014176 -0.071599  0.003004
# MJYRTOT   0.000274  0.052019 -0.153467 -0.085638 -0.007940 -0.074858
# MRDAYPYR -0.000690  0.020942 -0.050847 -0.040875 -0.004201 -0.015047
# MRDAYPMO  0.004657 -0.025533 -0.135971  0.024290 -0.018532 -0.012589
# MRDAYPWK  0.002288  0.041022 -0.146716 -0.066613 -0.008827 -0.068276
# MJDAY30A  0.003842  0.053856 -0.131019 -0.079324 -0.012935 -0.068158
# DEPNDALC -0.005689  0.032562 -0.044366 -0.022744 -0.011507 -0.033251
# DEPNDMRJ  0.003112  0.019697 -0.097214 -0.035871  0.003103 -0.041821
#
#            K6SCMON    K6SCYR   K6SCMAX  ALCYRTOT  ...   ALCDAYS   NODR30A  \
# CASEID   -0.000938  0.004392  0.001652  0.003289  ...  0.001422 -0.001051
# HEALTH2   0.230009  0.111629  0.188185 -0.075526  ... -0.082770 -0.020511
# AGE2     -0.150303 -0.131874 -0.162956  0.095130  ...  0.098041 -0.101362
# EDUCCAT2 -0.144880 -0.085507 -0.089385  0.153687  ...  0.171607 -0.000330
# EMPSTAT4  0.127097  0.061191  0.093900 -0.138875  ... -0.134868 -0.097436
# POVERTY2 -0.188226 -0.105164 -0.151910  0.121992  ...  0.133591  0.016673
# K6SCMON   1.000000  0.483747  0.837446 -0.016481  ... -0.024643  0.040135
# K6SCYR    0.483747  1.000000  0.660490 -0.014623  ... -0.018858  0.032733
# K6SCMAX   0.837446  0.660490  1.000000 -0.017053  ... -0.021267  0.040514
# ALCYRTOT -0.016481 -0.014623 -0.017053  1.000000  ...  0.813563  0.339324
# ALDAYPYR -0.006221  0.006173 -0.005317  0.285404  ...  0.273787  0.120256
# ALDAYPMO -0.000895  0.008720  0.008550  0.480329  ...  0.316372  0.257474
# ALDAYPWK -0.017421 -0.006356 -0.003501  0.834231  ...  0.713223  0.319093
# ALCDAYS  -0.024643 -0.018858 -0.021267  0.813563  ...  1.000000  0.338377
# NODR30A   0.040135  0.032733  0.040514  0.339324  ...  0.338377  1.000000
# DR5DAY    0.044676  0.033670  0.034952  0.476727  ...  0.562765  0.471037
# MJYRTOT   0.113815  0.076558  0.105100  0.146480  ...  0.136851  0.165673
# MRDAYPYR  0.042490  0.031786  0.037150  0.050719  ...  0.041927  0.053790
# MRDAYPMO  0.067247  0.064455  0.086259  0.106298  ...  0.106662  0.121491
# MRDAYPWK  0.107155  0.068853  0.096527  0.137442  ...  0.129863  0.156879
# MJDAY30A  0.103087  0.066780  0.095733  0.131876  ...  0.140690  0.158021
# DEPNDALC  0.149454  0.086907  0.141295  0.267727  ...  0.248192  0.240653
# DEPNDMRJ  0.105244  0.061065  0.096168  0.049818  ...  0.044467  0.065289
#
#             DR5DAY   MJYRTOT  MRDAYPYR  MRDAYPMO  MRDAYPWK  MJDAY30A  \
# CASEID    0.003982  0.000274 -0.000690  0.004657  0.002288  0.003842
# HEALTH2   0.005153  0.052019  0.020942 -0.025533  0.041022  0.053856
# AGE2     -0.045508 -0.153467 -0.050847 -0.135971 -0.146716 -0.131019
# EDUCCAT2 -0.014176 -0.085638 -0.040875  0.024290 -0.066613 -0.079324
# EMPSTAT4 -0.071599 -0.007940 -0.004201 -0.018532 -0.008827 -0.012935
# POVERTY2  0.003004 -0.074858 -0.015047 -0.012589 -0.068276 -0.068158
# K6SCMON   0.044676  0.113815  0.042490  0.067247  0.107155  0.103087
# K6SCYR    0.033670  0.076558  0.031786  0.064455  0.068853  0.066780
# K6SCMAX   0.034952  0.105100  0.037150  0.086259  0.096527  0.095733
# ALCYRTOT  0.476727  0.146480  0.050719  0.106298  0.137442  0.131876
# ALDAYPYR  0.192213  0.055309  0.075718  0.053137  0.029693  0.051012
# ALDAYPMO  0.176704  0.098119  0.041536  0.080429  0.078441  0.088761
# ALDAYPWK  0.408615  0.140499  0.026552  0.108681  0.145602  0.126129
# ALCDAYS   0.562765  0.136851  0.041927  0.106662  0.129863  0.140690
# NODR30A   0.471037  0.165673  0.053790  0.121491  0.156879  0.158021
# DR5DAY    1.000000  0.180448  0.051361  0.101411  0.169550  0.179177
# MJYRTOT   0.180448  1.000000  0.362678  0.055711  0.879641  0.900879
# MRDAYPYR  0.051361  0.362678  1.000000  0.354808  0.025597  0.352849
# MRDAYPMO  0.101411  0.055711  0.354808  1.000000  0.001345  0.084934
# MRDAYPWK  0.169550  0.879641  0.025597  0.001345  1.000000  0.798422
# MJDAY30A  0.179177  0.900879  0.352849  0.084934  0.798422  1.000000
# DEPNDALC  0.325508  0.104779  0.033801  0.070033  0.095594  0.093072
# DEPNDMRJ  0.054679  0.364824  0.123616  0.035723  0.324823  0.330216
#
#           DEPNDALC  DEPNDMRJ
# CASEID   -0.005689  0.003112
# HEALTH2   0.032562  0.019697
# AGE2     -0.044366 -0.097214
# EDUCCAT2 -0.022744 -0.035871
# EMPSTAT4 -0.011507  0.003103
# POVERTY2 -0.033251 -0.041821
# K6SCMON   0.149454  0.105244
# K6SCYR    0.086907  0.061065
# K6SCMAX   0.141295  0.096168
# ALCYRTOT  0.267727  0.049818
# ALDAYPYR  0.093106  0.022540
# ALDAYPMO  0.101921  0.035890
# ALDAYPWK  0.234441  0.050140
# ALCDAYS   0.248192  0.044467
# NODR30A   0.240653  0.065289
# DR5DAY    0.325508  0.054679
# MJYRTOT   0.104779  0.364824
# MRDAYPYR  0.033801  0.123616
# MRDAYPMO  0.070033  0.035723
# MRDAYPWK  0.095594  0.324823
# MJDAY30A  0.093072  0.330216
# DEPNDALC  1.000000  0.095005
# DEPNDMRJ  0.095005  1.000000
#
# [23 rows x 23 columns]

# %%
sns.distplot (df['K6SCMON'])
# Out:
# C:\Users\sharl\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#create df for alcohol, weed and K6 variables

# %%
df_alc= df[['ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO', 'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY']]
df_mr= df[['MJYRTOT', 'MRDAYPYR', 'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A']]
df_K6 = df[['K6SCMON', 'K6SCYR', 'K6SCMAX']]

# %%
#PCA visualisation

# %% [markdown]
# PCA is effected by scale so we need to scale the features in our data before applying PCA. Use StandardScaler to help  standardize the dataset’s features onto unit scale (mean = 0 and variance = 1) which is a requirement for the optimal performance of many machine learning algorithms.

# %%
#standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled_data_alc= StandardScaler().fit_transform(df_alc)
scaled_data_mr= StandardScaler().fit_transform(df_mr)
scaled_data_K6= StandardScaler().fit_transform(df_K6)

# %% [markdown]
# scaled_data_alc= df_alc.apply(np.log)
# scaled_data_mr= df_mr.apply(np.log)
# scaled_data_K6= df_K6.apply(np.log)

# %% [markdown]
# scaled_data_alc.head()

# %%
df_alc.shape
# Out:
# (31397, 7)

# %%
df_mr.shape
# Out:
# (31397, 5)

# %%
df_K6.shape
# Out:
# (31397, 3)

# %%
#PCA with Scikit Learn uses a very similar process to other preprocessing functions that come with SciKit Learn. 
#We instantiate a PCA object, find the principal components using the fit method, then apply the rotation and dimensionality reduction by calling transform().
#We can also specify how many components we want to keep when creating the PCA object.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1) #set how many dimensions

# %%
x_pca_alc =pca.fit_transform(scaled_data_alc)
x_pca_mr =pca.fit_transform(scaled_data_mr)
x_pca_K6 =pca.fit_transform(scaled_data_K6)

# %%
#Now we can transform this data to its first principal component.

# %%
scaled_data_alc.shape #shape before
# Out:
# (31397, 7)

# %%
x_pca_alc.shape  #shape after (to check if worked)
# Out:
# (31397, 1)

# %% [markdown]
# We've reduced the 7,5 and 3 dimensions to just 1.

# %%
#Unfortunately, with this great power of dimensionality reduction, comes the cost of being able to easily understand what these components represent.
#The components correspond to combinations of the original features, the components themselves are stored as an attribute of the fitted PCA object:

# %%
df_comp_alc =pd.DataFrame(data=x_pca_alc, columns= ['PCA_alcohol1'])
df_comp_mr =pd.DataFrame(data=x_pca_alc, columns= ['PCA_marijuana'])
df_comp_K6 =pd.DataFrame(data=x_pca_alc, columns= ['PCA K6'])

# %%
#now do regression on PCA data instead of whole df

# %% [markdown]
# ##Regression on PCA

# %%
df.columns
# Out:
# Index(['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2',
#        'K6SCMON', 'K6SCYR', 'K6SCMAX', 'ALCYRTOT', 'ALDAYPYR', 'ALDAYPMO',
#        'ALDAYPWK', 'ALCDAYS', 'NODR30A', 'DR5DAY', 'MJYRTOT', 'MRDAYPYR',
#        'MRDAYPMO', 'MRDAYPWK', 'MJDAY30A', 'DEPNDALC', 'DEPNDMRJ'],
#       dtype='object')

# %%
df_PCA =df[['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'K6SCMON', 'K6SCYR', 'K6SCMAX']]

# %%
df_PCA=df_PCA.assign(x_pca_alc = x_pca_alc, x_pca_mr=x_pca_mr, x_pca_K6=x_pca_K6)

# %%
df_PCA.describe()
# Out:
#              CASEID       HEALTH2          AGE2      EDUCCAT2      EMPSTAT4  \
# count  31397.000000  31397.000000  31397.000000  31397.000000  31397.000000
# mean   27678.878842      2.294157     13.262796      2.749944      2.025639
# std    15976.207356      0.941920      2.733378      1.006980      1.244613
# min        2.000000      1.000000      7.000000      1.000000      1.000000
# 25%    13791.000000      2.000000     11.000000      2.000000      1.000000
# 50%    27751.000000      2.000000     14.000000      3.000000      1.000000
# 75%    41569.000000      3.000000     15.000000      4.000000      3.000000
# max    55270.000000      4.000000     17.000000      4.000000      4.000000
#
#            POVERTY2       K6SCMON        K6SCYR       K6SCMAX     x_pca_alc  \
# count  31397.000000  31397.000000  31397.000000  31397.000000  3.139700e+04
# mean       2.396292      5.400484     10.373116      6.914387  4.882531e-16
# std        0.789310      4.343682      3.780581      5.655919  1.855212e+00
# min        1.000000      1.000000      0.000000      1.000000 -1.781718e+00
# 25%        2.000000      2.000000     10.291153      2.000000 -1.781718e+00
# 50%        3.000000      4.000000     10.291153      5.000000 -5.165163e-01
# 75%        3.000000      7.000000     10.291153     10.000000  7.623485e-01
# max        3.000000     24.000000     24.000000     24.000000  1.363443e+01
#
#            x_pca_mr      x_pca_K6
# count  3.139700e+04  3.139700e+04
# mean   7.643489e-16 -3.458711e-16
# std    1.684825e+00  1.527015e+00
# min   -5.454778e-01 -2.672188e+00
# 25%   -5.454778e-01 -1.009399e+00
# 50%   -5.454778e-01 -5.206608e-01
# 75%   -5.454778e-01  7.011841e-01
# max    8.745153e+00  6.256196e+00

# %%
sns.distplot(df_PCA['x_pca_K6'])
# Out:
# C:\Users\sharl\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(df_PCA) #creates histogram and correlation  scater plots

# %%
df_PCA.corr()
# Out:
#              CASEID   HEALTH2      AGE2  EDUCCAT2  EMPSTAT4  POVERTY2  \
# CASEID     1.000000  0.001501 -0.001621 -0.002547  0.001814 -0.010849
# HEALTH2    0.001501  1.000000  0.184055 -0.245700  0.202562 -0.160009
# AGE2      -0.001621  0.184055  1.000000  0.188046 -0.016998  0.213238
# EDUCCAT2  -0.002547 -0.245700  0.188046  1.000000 -0.228488  0.349779
# EMPSTAT4   0.001814  0.202562 -0.016998 -0.228488  1.000000 -0.277977
# POVERTY2  -0.010849 -0.160009  0.213238  0.349779 -0.277977  1.000000
# K6SCMON   -0.000938  0.230009 -0.150303 -0.144880  0.127097 -0.188226
# K6SCYR     0.004392  0.111629 -0.131874 -0.085507  0.061191 -0.105164
# K6SCMAX    0.001652  0.188185 -0.162956 -0.089385  0.093900 -0.151910
# x_pca_alc  0.001924 -0.073201  0.044094  0.141461 -0.161863  0.115452
# x_pca_mr   0.002247  0.050408 -0.157304 -0.081478 -0.011442 -0.072766
# x_pca_K6   0.001817  0.202695 -0.168912 -0.120940  0.107712 -0.169733
#
#             K6SCMON    K6SCYR   K6SCMAX  x_pca_alc  x_pca_mr  x_pca_K6
# CASEID    -0.000938  0.004392  0.001652   0.001924  0.002247  0.001817
# HEALTH2    0.230009  0.111629  0.188185  -0.073201  0.050408  0.202695
# AGE2      -0.150303 -0.131874 -0.162956   0.044094 -0.157304 -0.168912
# EDUCCAT2  -0.144880 -0.085507 -0.089385   0.141461 -0.081478 -0.120940
# EMPSTAT4   0.127097  0.061191  0.093900  -0.161863 -0.011442  0.107712
# POVERTY2  -0.188226 -0.105164 -0.151910   0.115452 -0.072766 -0.169733
# K6SCMON    1.000000  0.483747  0.837446  -0.000144  0.116999  0.888595
# K6SCYR     0.483747  1.000000  0.660490   0.003634  0.078354  0.795662
# K6SCMAX    0.837446  0.660490  1.000000   0.003421  0.108474  0.953426
# x_pca_alc -0.000144  0.003634  0.003421   1.000000  0.198329  0.002584
# x_pca_mr   0.116999  0.078354  0.108474   0.198329  1.000000  0.115680
# x_pca_K6   0.888595  0.795662  0.953426   0.002584  0.115680  1.000000

# %%
sns.heatmap(df_PCA.corr(), annot=True)

# %%
df_PCA.columns
# Out:
# Index(['CASEID', 'HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2',
#        'K6SCMON', 'K6SCYR', 'K6SCMAX', 'x_pca_alc', 'x_pca_mr', 'x_pca_K6'],
#       dtype='object')

# %% [markdown]
# Training a linear reg model with scikit.
# Split the data into features to train on (x array) and target variable(y).

# %%
X = df_PCA[['HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'x_pca_alc', 'x_pca_mr']] #education and employment is non linear, maybe better logistic regression

# %%
y = df_PCA['K6SCMON']

# %%
from sklearn.model_selection  import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101) #40% test, #random split seed 101

# %% [markdown]
# create and train the model

# %%
from sklearn.linear_model import LinearRegression #import a reg model

# %%
lm = LinearRegression()  #initiate and instance of regression model

# %%
lm.fit(X_train, y_train) #train/fit my model on training data
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#evaluate the model, check it's coefficient and see how can be interpreted

# %%
print(lm.intercept_)  #print the intercept
# Out:
# 7.3377167907414425

# %%
lm.coef_ #grab the coefficience for each feautre
# Out:
# array([ 1.04864131, -0.25355822, -0.05380838,  0.22126691, -0.51025871,
#         0.08961218,  0.15352736])

# %%
X_train.columns
# Out:
# Index(['HEALTH2', 'AGE2', 'EDUCCAT2', 'EMPSTAT4', 'POVERTY2', 'x_pca_alc',
#        'x_pca_mr'],
#       dtype='object')

# %%
cdf = pd.DataFrame(lm.coef_,X_train.columns, columns=['coefficient'])

# %%
cdf #cdf as coefficient dataFrame
# Out:
#            coefficient
# HEALTH2       1.048641
# AGE2         -0.253558
# EDUCCAT2     -0.053808
# EMPSTAT4      0.221267
# POVERTY2     -0.510259
# x_pca_alc     0.089612
# x_pca_mr      0.153527

# %% [markdown]
# #predictions

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([5.30426905, 5.75496262, 7.38060467, ..., 6.3669719 , 5.10320378,
#        7.50359075])

# %% [markdown]
# #test how far off is our prediction from the actual Y (target variable)

# %%
plt.scatter(y_test, predictions)

# %%
sns.distplot(y_test-predictions) #residual histogram
# Out:
# C:\Users\sharl\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #normal distribution implies linear regression is good choice of model

# %% [markdown]
# #regression evaluation metrics

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions) #MAE
# Out:
# 3.103397740704144

# %%
metrics.mean_squared_error(y_test, predictions) #MSE ---this one 'punishes' large erorrs
# Out:
# 16.510472557029082

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions)) #RMSE --- interpreted in 'y' units
# Out:
# 4.063308080496615

# %% [markdown]
# ##Logistic regression???

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions_linear = logmodel.predict(X_test)

# %%
plt.scatter(y_test, predictions_linear)

# %%
##evaluations

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-49b4b26ceb45> in <module>()
# ----> 1 print(classification_report(y_test,predictions))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits)
#    1419
#    1420     if labels is None:
# -> 1421         labels = unique_labels(y_true, y_pred)
#    1422     else:
#    1423         labels = np.asarray(labels)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in unique_labels(*ys)
#      80
#      81     if len(ys_types) > 1:
# ---> 82         raise ValueError("Mix type of y not allowed, got types %s" % ys_types)
#      83
#      84     label_type = ys_types.pop()
#
# ValueError: Mix type of y not allowed, got types {'multiclass', 'continuous'}
